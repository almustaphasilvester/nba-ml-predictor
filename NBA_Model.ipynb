# %%
import pickle
import tensorflow as tf
import pandas as pd
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Read and Process Data

# %%
# All Games
df_games = pd.read_parquet("Data/nba_games.parquet").reset_index(drop=True).fillna(0)
# Player Games
df_player_games = pd.read_parquet("Data/player_game_stats.parquet").reset_index(drop=True).fillna(0)
# Team Rosters
df_team_rosters = pd.read_parquet("Data/team_rosters.parquet")

# %%
#Add Home Vs Away -> 0 = Away | 1 = Home
def home_or_away(matchup):

    if "@" in matchup:
        return 0
    else:
        return 1

# %%
df_games["side"] = df_games["MATCHUP"].apply(lambda x: home_or_away(x))

# %%
df_player_games = pd.merge(df_player_games, df_games[["MATCHUP", "GAME_ID", "TEAM_ID", "side"]], how="inner", left_on=["MATCHUP", "Game_ID"], right_on=["MATCHUP", "GAME_ID"])

# %%
def adjust_dtypes(df):

    use_category_cols = ["SEASON_ID", "GAME_ID", "TEAM_ID"]
    use_string_cols = ["TEAM_ABBREVIATION", "TEAM_NAME", "MATCHUP", "WL"]

    df["GAME_DATE"] = pd.to_datetime(df["GAME_DATE"])

    for col in use_category_cols:
        try:
            df[col] = df[col].astype('category')
        except Exception as e:
            df["Game_ID"] = df["Game_ID"].astype('category')
            df["Player_ID"] = df["Player_ID"].astype('category')

    for col in use_string_cols:
        if col in df.columns:
            df[col] = df[col].astype(str)
        else:
            pass

    return df

# %%
def get_game_averages(df):

    use_cols = ['PTS', 'FGM', 'FGA', 'FG_PCT',
       'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB',
       'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF']

    for col in use_cols:
        df[f"AVG_{col}"] = df.sort_values(["GAME_DATE"]).groupby(["TEAM_ID"])[col].expanding().mean().reset_index(0,drop=True)
    
    return df

# %%
def get_player_averages(df):

    use_cols = ['PTS', 'FGM', 'FGA', 'FG_PCT',
       'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB',
       'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF']

    for col in use_cols:
        df[f"AVG_{col}"] = df.sort_values(["GAME_DATE"]).groupby(["Player_ID"])[col].expanding().mean().reset_index(0,drop=True)
    
    return df

# %%
def create_target(Match, WL):
    if "@" in Match:
        if WL == "W":
            return 0
        else:
            return 1
    else:
        if WL == "W":
            return 1
        else:
            return 0

# %%
# Adjust Data Types
df_player_games = adjust_dtypes(df_player_games)
# Group By Team and Sort By Date - Calculate Running Average of Game Stats
df_games = get_game_averages(df_games)
# Group By Player and Sort By Date - Calculate Running Average of Player Stats
df_player_games = get_player_averages(df_player_games)

# %% [markdown]
# ## Create Target Columns and Filter Out Bad Data

# %%
# Establish Win / Lose
df_games["target"] = df_games[["MATCHUP","WL"]].apply(lambda x: create_target(x[0],x[1]), axis=1)
# Establish Training Data
df_player_games[["target_id", "side"]] = df_player_games.sort_values(["GAME_DATE"]).groupby(["Player_ID"])[["Game_ID", "side"]].shift(-1)
df_games[["target_id", "side", "target"]] = df_games.sort_values(["GAME_DATE"]).groupby(["TEAM_ID"])[["GAME_ID", "side", "target"]].shift(-1)
# Drop Bad Training Data
df_player_games = df_player_games.dropna(subset="target_id")
df_games = df_games.dropna(subset="target_id")
df_player_games = df_player_games[df_player_games.groupby(["TEAM_ID","target_id"])["target_id"].transform("count")>= 10]
df_player_games = df_player_games[df_player_games.groupby(["target_id"])["target_id"].transform("count")>= 20]
df_games = df_games[df_games.groupby(["TEAM_ID", "target_id"])["target_id"].transform("count") == 1]
df_games = df_games[df_games.groupby(["target_id"])["target_id"].transform("count") == 2]

# %%
# Make Sure Both Datasets Line Up
df_player_games = df_player_games.loc[df_player_games["target_id"].isin(df_games["target_id"])]
df_games = df_games.loc[df_games["target_id"].isin(df_player_games["target_id"])]

# %% [markdown]
# ## Create A Generator to Feed the Tensorflow Model

# %%
# OUTPUT --> HOME PLAYER AVERAGE + HOME TEAM AVERAGE + AWAY PLAYER AVERAGE + AWAY TEAM AVERAGE

def generate_data():
    
    for target_game in df_games.target_id.unique():

        # Game Data
        game = df_games[df_games["target_id"].values == target_game]
        home_team = game[game["side"].values == 1]
        away_team = game[game["side"].values == 0]

        # Team Data
        team = df_player_games[df_player_games["target_id"].values == target_game]
        home_players = team[team["side"].values == 1]
        away_players= team[team["side"].values == 0]
        home_players = home_players.sort_values("AVG_PTS", ascending=False).head(10)
        away_players = away_players.sort_values("AVG_PTS", ascending=False).head(10)

        # Target
        try:
            target = home_team["target"].values[0]
        except Exception as e:
            print(f"Target ID: {target}; Team Issue")
            continue

        # Drop Uneccesary Data From Columns
        home_team = home_team.drop(['SEASON_ID', 'TEAM_ID', 'TEAM_ABBREVIATION', 'TEAM_NAME', 'GAME_ID',
       'GAME_DATE', 'MATCHUP', 'WL', 'MIN', 'PTS', 'FGM', 'FGA', 'FG_PCT',
       'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB',
       'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PLUS_MINUS','target', 'target_id', 'side'], axis=1)

        away_team = away_team.drop(['SEASON_ID', 'TEAM_ID', 'TEAM_ABBREVIATION', 'TEAM_NAME', 'GAME_ID',
       'GAME_DATE', 'MATCHUP', 'WL', 'MIN', 'PTS', 'FGM', 'FGA', 'FG_PCT',
       'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB',
       'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PLUS_MINUS','target', 'target_id', 'side'], axis=1)

        home_players = home_players.drop(['SEASON_ID', 'Player_ID', 'Game_ID', 'GAME_DATE', 'MATCHUP', 'WL',
       'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA',
       'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF',
       'PTS', 'PLUS_MINUS', 'VIDEO_AVAILABLE', 'GAME_ID', 'TEAM_ID', 'target_id','side'], axis=1)

        away_players = away_players.drop(['SEASON_ID', 'Player_ID', 'Game_ID', 'GAME_DATE', 'MATCHUP', 'WL',
       'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA',
       'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF',
       'PTS', 'PLUS_MINUS', 'VIDEO_AVAILABLE', 'GAME_ID', 'TEAM_ID', 'target_id','side'],axis=1)

        if len(home_team) != 1 or len(away_team) != 1:
            #print(f"Target ID: {target_game}; Team Issue")
            continue
        elif len(home_players) != 10 or len(away_players) != 10:
            #print(f"Target ID: {target_game}; Player Issue")
            continue
        else:
            pass

        yield (home_players, home_team, away_players, away_team), target

# %% [markdown]
# # Set Up TF Data Pipeline

# %%
# Establish Size of Splits
DATASET_SIZE = 19011
train_size = int(0.8 * DATASET_SIZE)
val_size = int(0.1 * DATASET_SIZE)
test_size = int(0.1 * DATASET_SIZE)

# %%
output_signature = ((
                    tf.TensorSpec(shape = (10, 18), dtype = tf.float32),
                    tf.TensorSpec(shape = (1, 18), dtype = tf.float32),
                    tf.TensorSpec(shape = (10, 18), dtype = tf.float32),
                    tf.TensorSpec(shape = (1, 18), dtype = tf.float32)),
                    tf.TensorSpec(shape = (), dtype = tf.int16))

# Create TF Dataset and Shuffle
ds = tf.data.Dataset.from_generator(generate_data, output_signature=output_signature).shuffle(19017, seed=1997, reshuffle_each_iteration = False)#1738)
# Out:
# Metal device set to: Apple M1
#
# systemMemory: 8.00 GB
# maxCacheSize: 2.67 GB
# 2023-03-29 15:44:02.660581: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-03-29 15:44:02.660604: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
# Split Full Dataset into Train, Validation, Test
train_ds = ds.take(train_size)
val_ds = ds.skip(train_size).take(val_size)
test_ds = ds.skip(train_size).skip(val_size).batch(2056)

# %%
# Cache and Pre Fetch Data
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(AUTOTUNE)
val_ds = val_ds.cache().prefetch(AUTOTUNE)

# %%
# Batch Size
batch_size = 2056

# Establish Batch Size
train_ds = train_ds.batch(batch_size)
val_ds = val_ds.batch(batch_size)

# %%
# Define Steps Per Epoch & Validation Steps
steps_per_epoch = train_size//batch_size
val_steps = val_size//batch_size

# %% [markdown]
# # Create Model

# %%
def create_model():
    
    # Create Inputs For Numerical Data
    home_player_input = tf.keras.Input(shape = (10, 18), name="home_player_input")
    home_team_input = tf.keras.Input(shape = (1, 18), name="home_team_input")
    away_player_input = tf.keras.Input(shape = (10, 18), name="away_player_input")
    away_team_input = tf.keras.Input(shape = (1, 18), name="away_team_input")
    
    # Create First Branch
    x = tf.keras.layers.Dense(18, activation='relu')(home_team_input)
    x = tf.keras.layers.Normalization()(x)
    x = tf.keras.layers.Dense(18, activation='relu')(x)

    # Create Second Branch
    y = tf.keras.layers.Dense(180, activation='relu')(home_player_input)
    y = tf.keras.layers.Normalization()(y)
    y = tf.keras.layers.Dense(18, activation='relu')(y)

    # Create Third Brandch
    z = tf.keras.layers.Dense(18, activation='relu')(away_team_input)
    z = tf.keras.layers.Normalization()(z)
    z = tf.keras.layers.Dense(18, activation='relu')(z)

    # Create Fourth Branch
    w = tf.keras.layers.Dense(180, activation='relu')(away_player_input)
    w = tf.keras.layers.Normalization()(w)
    w = tf.keras.layers.Dense(18, activation='relu')(w)
    
    # Combine Branches
    xyz = tf.keras.layers.concatenate([x,y,z,w], axis=1)
    xyz = tf.keras.layers.Dense(18, activation='relu')(xyz)
    xyz = tf.keras.layers.Dense(18, activation='relu')(xyz)
    xyz = tf.keras.layers.Flatten()(xyz)
    output = tf.keras.layers.Dense(1, activation='sigmoid')(xyz)
    
    # Create Model
    model = tf.keras.Model(inputs=[home_player_input, home_team_input, away_player_input, away_team_input], outputs=output)
    
    return model

# %%
model = create_model()

model.compile(
    loss=tf.keras.losses.BinaryCrossentropy(),
    optimizer=tf.keras.optimizers.legacy.Adam(learning_rate=0.00005),
    run_eagerly=True,
    metrics=[
        tf.keras.metrics.AUC(num_thresholds=10000),
        "accuracy"
    ]
)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  home_team_input (InputLayer)   [(None, 1, 18)]      0           []
#
#  home_player_input (InputLayer)  [(None, 10, 18)]    0           []
#
#  away_team_input (InputLayer)   [(None, 1, 18)]      0           []
#
#  away_player_input (InputLayer)  [(None, 10, 18)]    0           []
#
#  dense (Dense)                  (None, 1, 18)        342         ['home_team_input[0][0]']
#
#  dense_2 (Dense)                (None, 10, 180)      3420        ['home_player_input[0][0]']
#
#  dense_4 (Dense)                (None, 1, 18)        342         ['away_team_input[0][0]']
#
#  dense_6 (Dense)                (None, 10, 180)      3420        ['away_player_input[0][0]']
#
#  normalization (Normalization)  (None, 1, 18)        37          ['dense[0][0]']
#
#  normalization_1 (Normalization  (None, 10, 180)     361         ['dense_2[0][0]']
#  )
#
#  normalization_2 (Normalization  (None, 1, 18)       37          ['dense_4[0][0]']
#  )
#
#  normalization_3 (Normalization  (None, 10, 180)     361         ['dense_6[0][0]']
#  )
#
#  dense_1 (Dense)                (None, 1, 18)        342         ['normalization[0][0]']
#
#  dense_3 (Dense)                (None, 10, 18)       3258        ['normalization_1[0][0]']
#
#  dense_5 (Dense)                (None, 1, 18)        342         ['normalization_2[0][0]']
#
#  dense_7 (Dense)                (None, 10, 18)       3258        ['normalization_3[0][0]']
#
#  concatenate (Concatenate)      (None, 22, 18)       0           ['dense_1[0][0]',
#                                                                   'dense_3[0][0]',
#                                                                   'dense_5[0][0]',
#                                                                   'dense_7[0][0]']
#
#  dense_8 (Dense)                (None, 22, 18)       342         ['concatenate[0][0]']
#
#  dense_9 (Dense)                (None, 22, 18)       342         ['dense_8[0][0]']
#
#  flatten (Flatten)              (None, 396)          0           ['dense_9[0][0]']
#
#  dense_10 (Dense)               (None, 1)            397         ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 16,601
# Trainable params: 15,805
# Non-trainable params: 796
# __________________________________________________________________________________________________

# %% [markdown]
# # Train Model

# %%
val_auc_call = tf.keras.callbacks.EarlyStopping(monitor="val_accuracy", restore_best_weights=True, start_from_epoch=200, patience=50)
auc_call = tf.keras.callbacks.EarlyStopping(monitor="accuracy", restore_best_weights=True, start_from_epoch=200, patience=50)
val_loss = tf.keras.callbacks.EarlyStopping(monitor="val_loss", restore_best_weights=True, start_from_epoch=200, patience=50)


callbacks = [val_auc_call, auc_call, val_loss]

# %%
history = model.fit(train_ds, epochs=2000, validation_data=val_ds, verbose=2, callbacks=callbacks, class_weight={0:1.25, 1:1})
# Out:
# Epoch 1/2000
# 2023-03-29 15:44:03.287173: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-03-29 15:44:13.299867: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 1436 of 19017
# 2023-03-29 15:44:23.297597: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 2887 of 19017
# 2023-03-29 15:44:33.302092: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 4339 of 19017
# 2023-03-29 15:44:43.301305: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 5792 of 19017
# 2023-03-29 15:44:53.298689: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 7246 of 19017
# 2023-03-29 15:45:03.300803: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 8701 of 19017
# 2023-03-29 15:45:13.300437: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 10153 of 19017
# 2023-03-29 15:45:23.300796: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 11607 of 19017
# 2023-03-29 15:45:33.299224: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 13061 of 19017
# 2023-03-29 15:45:43.298131: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 14518 of 19017
# 2023-03-29 15:45:53.304177: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 15931 of 19017
# 2023-03-29 15:46:03.302531: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 17343 of 19017
# 2023-03-29 15:46:13.298798: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 18814 of 19017
# 2023-03-29 15:46:14.635846: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:417] Shuffle buffer filled.
# 2023-03-29 15:46:25.829669: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 1468 of 19017
# 2023-03-29 15:46:35.827412: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 2939 of 19017
# 2023-03-29 15:46:45.828902: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 4409 of 19017
# 2023-03-29 15:46:55.827351: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 5866 of 19017
# 2023-03-29 15:47:05.831727: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 7212 of 19017
# 2023-03-29 15:47:15.828218: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 8678 of 19017
# 2023-03-29 15:47:25.828876: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 10016 of 19017
# 2023-03-29 15:47:35.826574: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 11280 of 19017
# 2023-03-29 15:47:45.828523: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 12524 of 19017
# 2023-03-29 15:47:55.828381: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 13837 of 19017
# 2023-03-29 15:48:05.830111: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 15145 of 19017
# 2023-03-29 15:48:15.832621: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 16406 of 19017
# 2023-03-29 15:48:25.831393: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 17570 of 19017
# 2023-03-29 15:48:35.834387: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 18748 of 19017
# 2023-03-29 15:48:38.070818: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:417] Shuffle buffer filled.
# 8/8 - 275s - loss: 1.0485 - auc: 0.5483 - accuracy: 0.6459 - val_loss: 0.7905 - val_auc: 0.5396 - val_accuracy: 0.6465 - 275s/epoch - 34s/step
# Epoch 2/2000
# 8/8 - 1s - loss: 0.9139 - auc: 0.5447 - accuracy: 0.6459 - val_loss: 0.7100 - val_auc: 0.5318 - val_accuracy: 0.6465 - 1s/epoch - 134ms/step
# Epoch 3/2000
# 8/8 - 1s - loss: 0.8167 - auc: 0.5410 - accuracy: 0.6459 - val_loss: 0.6644 - val_auc: 0.5254 - val_accuracy: 0.6465 - 792ms/epoch - 99ms/step
# Epoch 4/2000
# 8/8 - 1s - loss: 0.7603 - auc: 0.5390 - accuracy: 0.6459 - val_loss: 0.6495 - val_auc: 0.5213 - val_accuracy: 0.6465 - 1s/epoch - 132ms/step
# Epoch 5/2000
# 8/8 - 1s - loss: 0.7370 - auc: 0.5394 - accuracy: 0.6460 - val_loss: 0.6521 - val_auc: 0.5201 - val_accuracy: 0.6465 - 839ms/epoch - 105ms/step
# Epoch 6/2000
# 8/8 - 1s - loss: 0.7321 - auc: 0.5414 - accuracy: 0.6459 - val_loss: 0.6581 - val_auc: 0.5207 - val_accuracy: 0.6465 - 745ms/epoch - 93ms/step
# Epoch 7/2000
# 8/8 - 1s - loss: 0.7324 - auc: 0.5437 - accuracy: 0.6456 - val_loss: 0.6603 - val_auc: 0.5223 - val_accuracy: 0.6439 - 756ms/epoch - 95ms/step
# Epoch 8/2000
# 8/8 - 1s - loss: 0.7323 - auc: 0.5461 - accuracy: 0.6459 - val_loss: 0.6588 - val_auc: 0.5245 - val_accuracy: 0.6454 - 600ms/epoch - 75ms/step
# Epoch 9/2000
# 8/8 - 1s - loss: 0.7314 - auc: 0.5487 - accuracy: 0.6456 - val_loss: 0.6561 - val_auc: 0.5272 - val_accuracy: 0.6465 - 751ms/epoch - 94ms/step
# Epoch 10/2000
# 8/8 - 1s - loss: 0.7307 - auc: 0.5513 - accuracy: 0.6466 - val_loss: 0.6539 - val_auc: 0.5297 - val_accuracy: 0.6460 - 632ms/epoch - 79ms/step
# Epoch 11/2000
# 8/8 - 1s - loss: 0.7302 - auc: 0.5540 - accuracy: 0.6462 - val_loss: 0.6526 - val_auc: 0.5322 - val_accuracy: 0.6465 - 651ms/epoch - 81ms/step
# Epoch 12/2000
# 8/8 - 1s - loss: 0.7299 - auc: 0.5567 - accuracy: 0.6463 - val_loss: 0.6521 - val_auc: 0.5350 - val_accuracy: 0.6465 - 668ms/epoch - 83ms/step
# Epoch 13/2000
# 8/8 - 1s - loss: 0.7296 - auc: 0.5593 - accuracy: 0.6464 - val_loss: 0.6520 - val_auc: 0.5378 - val_accuracy: 0.6465 - 672ms/epoch - 84ms/step
# Epoch 14/2000
# 8/8 - 1s - loss: 0.7291 - auc: 0.5622 - accuracy: 0.6460 - val_loss: 0.6519 - val_auc: 0.5416 - val_accuracy: 0.6470 - 646ms/epoch - 81ms/step
# Epoch 15/2000
# 8/8 - 1s - loss: 0.7287 - auc: 0.5655 - accuracy: 0.6466 - val_loss: 0.6518 - val_auc: 0.5457 - val_accuracy: 0.6465 - 620ms/epoch - 77ms/step
# Epoch 16/2000
# 8/8 - 1s - loss: 0.7281 - auc: 0.5695 - accuracy: 0.6463 - val_loss: 0.6515 - val_auc: 0.5500 - val_accuracy: 0.6465 - 612ms/epoch - 77ms/step
# Epoch 17/2000
# 8/8 - 1s - loss: 0.7275 - auc: 0.5729 - accuracy: 0.6461 - val_loss: 0.6511 - val_auc: 0.5543 - val_accuracy: 0.6470 - 602ms/epoch - 75ms/step
# Epoch 18/2000
# 8/8 - 1s - loss: 0.7269 - auc: 0.5761 - accuracy: 0.6458 - val_loss: 0.6506 - val_auc: 0.5583 - val_accuracy: 0.6454 - 627ms/epoch - 78ms/step
# Epoch 19/2000
# 8/8 - 1s - loss: 0.7263 - auc: 0.5788 - accuracy: 0.6462 - val_loss: 0.6503 - val_auc: 0.5605 - val_accuracy: 0.6476 - 658ms/epoch - 82ms/step
# Epoch 20/2000
# 8/8 - 1s - loss: 0.7258 - auc: 0.5809 - accuracy: 0.6455 - val_loss: 0.6500 - val_auc: 0.5623 - val_accuracy: 0.6460 - 641ms/epoch - 80ms/step
# Epoch 21/2000
# 8/8 - 1s - loss: 0.7253 - auc: 0.5826 - accuracy: 0.6447 - val_loss: 0.6496 - val_auc: 0.5636 - val_accuracy: 0.6454 - 642ms/epoch - 80ms/step
# Epoch 22/2000
# 8/8 - 1s - loss: 0.7249 - auc: 0.5842 - accuracy: 0.6448 - val_loss: 0.6492 - val_auc: 0.5651 - val_accuracy: 0.6454 - 990ms/epoch - 124ms/step
# Epoch 23/2000
# 8/8 - 1s - loss: 0.7245 - auc: 0.5858 - accuracy: 0.6446 - val_loss: 0.6488 - val_auc: 0.5670 - val_accuracy: 0.6444 - 744ms/epoch - 93ms/step
# Epoch 24/2000
# 8/8 - 1s - loss: 0.7241 - auc: 0.5876 - accuracy: 0.6441 - val_loss: 0.6484 - val_auc: 0.5693 - val_accuracy: 0.6454 - 710ms/epoch - 89ms/step
# Epoch 25/2000
# 8/8 - 1s - loss: 0.7236 - auc: 0.5899 - accuracy: 0.6439 - val_loss: 0.6479 - val_auc: 0.5725 - val_accuracy: 0.6449 - 667ms/epoch - 83ms/step
# Epoch 26/2000
# 8/8 - 1s - loss: 0.7229 - auc: 0.5927 - accuracy: 0.6443 - val_loss: 0.6473 - val_auc: 0.5758 - val_accuracy: 0.6444 - 692ms/epoch - 86ms/step
# Epoch 27/2000
# 8/8 - 1s - loss: 0.7223 - auc: 0.5953 - accuracy: 0.6445 - val_loss: 0.6468 - val_auc: 0.5786 - val_accuracy: 0.6439 - 710ms/epoch - 89ms/step
# Epoch 28/2000
# 8/8 - 1s - loss: 0.7218 - auc: 0.5978 - accuracy: 0.6450 - val_loss: 0.6462 - val_auc: 0.5813 - val_accuracy: 0.6444 - 1s/epoch - 130ms/step
# Epoch 29/2000
# 8/8 - 1s - loss: 0.7213 - auc: 0.6000 - accuracy: 0.6454 - val_loss: 0.6458 - val_auc: 0.5836 - val_accuracy: 0.6444 - 702ms/epoch - 88ms/step
# Epoch 30/2000
# 8/8 - 1s - loss: 0.7209 - auc: 0.6021 - accuracy: 0.6455 - val_loss: 0.6454 - val_auc: 0.5859 - val_accuracy: 0.6444 - 636ms/epoch - 79ms/step
# Epoch 31/2000
# 8/8 - 1s - loss: 0.7204 - auc: 0.6041 - accuracy: 0.6459 - val_loss: 0.6450 - val_auc: 0.5882 - val_accuracy: 0.6449 - 751ms/epoch - 94ms/step
# Epoch 32/2000
# 8/8 - 1s - loss: 0.7199 - auc: 0.6060 - accuracy: 0.6459 - val_loss: 0.6446 - val_auc: 0.5901 - val_accuracy: 0.6454 - 653ms/epoch - 82ms/step
# Epoch 33/2000
# 8/8 - 1s - loss: 0.7195 - auc: 0.6076 - accuracy: 0.6462 - val_loss: 0.6442 - val_auc: 0.5918 - val_accuracy: 0.6449 - 653ms/epoch - 82ms/step
# Epoch 34/2000
# 8/8 - 1s - loss: 0.7191 - auc: 0.6092 - accuracy: 0.6461 - val_loss: 0.6438 - val_auc: 0.5936 - val_accuracy: 0.6454 - 945ms/epoch - 118ms/step
# Epoch 35/2000
# 8/8 - 1s - loss: 0.7187 - auc: 0.6107 - accuracy: 0.6463 - val_loss: 0.6434 - val_auc: 0.5955 - val_accuracy: 0.6470 - 874ms/epoch - 109ms/step
# Epoch 36/2000
# 8/8 - 1s - loss: 0.7184 - auc: 0.6123 - accuracy: 0.6465 - val_loss: 0.6430 - val_auc: 0.5972 - val_accuracy: 0.6465 - 630ms/epoch - 79ms/step
# Epoch 37/2000
# 8/8 - 1s - loss: 0.7180 - auc: 0.6140 - accuracy: 0.6466 - val_loss: 0.6427 - val_auc: 0.5991 - val_accuracy: 0.6470 - 691ms/epoch - 86ms/step
# Epoch 38/2000
# 8/8 - 1s - loss: 0.7176 - auc: 0.6158 - accuracy: 0.6475 - val_loss: 0.6424 - val_auc: 0.6006 - val_accuracy: 0.6476 - 646ms/epoch - 81ms/step
# Epoch 39/2000
# 8/8 - 1s - loss: 0.7172 - auc: 0.6175 - accuracy: 0.6478 - val_loss: 0.6420 - val_auc: 0.6018 - val_accuracy: 0.6476 - 634ms/epoch - 79ms/step
# Epoch 40/2000
# 8/8 - 1s - loss: 0.7169 - auc: 0.6191 - accuracy: 0.6483 - val_loss: 0.6416 - val_auc: 0.6032 - val_accuracy: 0.6486 - 616ms/epoch - 77ms/step
# Epoch 41/2000
# 8/8 - 1s - loss: 0.7165 - auc: 0.6205 - accuracy: 0.6484 - val_loss: 0.6413 - val_auc: 0.6047 - val_accuracy: 0.6486 - 660ms/epoch - 82ms/step
# Epoch 42/2000
# 8/8 - 1s - loss: 0.7162 - auc: 0.6220 - accuracy: 0.6485 - val_loss: 0.6409 - val_auc: 0.6063 - val_accuracy: 0.6481 - 620ms/epoch - 78ms/step
# Epoch 43/2000
# 8/8 - 1s - loss: 0.7158 - auc: 0.6234 - accuracy: 0.6491 - val_loss: 0.6406 - val_auc: 0.6078 - val_accuracy: 0.6481 - 628ms/epoch - 79ms/step
# Epoch 44/2000
# 8/8 - 1s - loss: 0.7155 - auc: 0.6248 - accuracy: 0.6493 - val_loss: 0.6402 - val_auc: 0.6095 - val_accuracy: 0.6476 - 942ms/epoch - 118ms/step
# Epoch 45/2000
# 8/8 - 1s - loss: 0.7151 - auc: 0.6263 - accuracy: 0.6495 - val_loss: 0.6399 - val_auc: 0.6110 - val_accuracy: 0.6470 - 722ms/epoch - 90ms/step
# Epoch 46/2000
# 8/8 - 1s - loss: 0.7147 - auc: 0.6279 - accuracy: 0.6498 - val_loss: 0.6395 - val_auc: 0.6125 - val_accuracy: 0.6481 - 630ms/epoch - 79ms/step
# Epoch 47/2000
# 8/8 - 1s - loss: 0.7143 - auc: 0.6296 - accuracy: 0.6498 - val_loss: 0.6392 - val_auc: 0.6141 - val_accuracy: 0.6491 - 623ms/epoch - 78ms/step
# Epoch 48/2000
# 8/8 - 1s - loss: 0.7139 - auc: 0.6314 - accuracy: 0.6504 - val_loss: 0.6388 - val_auc: 0.6158 - val_accuracy: 0.6491 - 612ms/epoch - 76ms/step
# Epoch 49/2000
# 8/8 - 1s - loss: 0.7134 - auc: 0.6333 - accuracy: 0.6510 - val_loss: 0.6384 - val_auc: 0.6177 - val_accuracy: 0.6486 - 646ms/epoch - 81ms/step
# Epoch 50/2000
# 8/8 - 1s - loss: 0.7129 - auc: 0.6354 - accuracy: 0.6510 - val_loss: 0.6380 - val_auc: 0.6194 - val_accuracy: 0.6497 - 614ms/epoch - 77ms/step
# Epoch 51/2000
# 8/8 - 1s - loss: 0.7124 - auc: 0.6373 - accuracy: 0.6514 - val_loss: 0.6375 - val_auc: 0.6212 - val_accuracy: 0.6502 - 703ms/epoch - 88ms/step
# Epoch 52/2000
# 8/8 - 1s - loss: 0.7119 - auc: 0.6391 - accuracy: 0.6515 - val_loss: 0.6370 - val_auc: 0.6230 - val_accuracy: 0.6491 - 853ms/epoch - 107ms/step
# Epoch 53/2000
# 8/8 - 1s - loss: 0.7115 - auc: 0.6407 - accuracy: 0.6517 - val_loss: 0.6366 - val_auc: 0.6248 - val_accuracy: 0.6486 - 718ms/epoch - 90ms/step
# Epoch 54/2000
# 8/8 - 1s - loss: 0.7110 - auc: 0.6423 - accuracy: 0.6524 - val_loss: 0.6362 - val_auc: 0.6266 - val_accuracy: 0.6491 - 912ms/epoch - 114ms/step
# Epoch 55/2000
# 8/8 - 1s - loss: 0.7106 - auc: 0.6438 - accuracy: 0.6528 - val_loss: 0.6358 - val_auc: 0.6280 - val_accuracy: 0.6491 - 619ms/epoch - 77ms/step
# Epoch 56/2000
# 8/8 - 1s - loss: 0.7102 - auc: 0.6452 - accuracy: 0.6531 - val_loss: 0.6354 - val_auc: 0.6293 - val_accuracy: 0.6486 - 764ms/epoch - 95ms/step
# Epoch 57/2000
# 8/8 - 1s - loss: 0.7098 - auc: 0.6465 - accuracy: 0.6533 - val_loss: 0.6351 - val_auc: 0.6304 - val_accuracy: 0.6497 - 1s/epoch - 151ms/step
# Epoch 58/2000
# 8/8 - 1s - loss: 0.7094 - auc: 0.6478 - accuracy: 0.6540 - val_loss: 0.6348 - val_auc: 0.6316 - val_accuracy: 0.6497 - 1s/epoch - 140ms/step
# Epoch 59/2000
# 8/8 - 1s - loss: 0.7090 - auc: 0.6491 - accuracy: 0.6544 - val_loss: 0.6344 - val_auc: 0.6329 - val_accuracy: 0.6502 - 732ms/epoch - 91ms/step
# Epoch 60/2000
# 8/8 - 1s - loss: 0.7086 - auc: 0.6503 - accuracy: 0.6543 - val_loss: 0.6341 - val_auc: 0.6341 - val_accuracy: 0.6512 - 686ms/epoch - 86ms/step
# Epoch 61/2000
# 8/8 - 1s - loss: 0.7082 - auc: 0.6515 - accuracy: 0.6550 - val_loss: 0.6337 - val_auc: 0.6353 - val_accuracy: 0.6518 - 1s/epoch - 134ms/step
# Epoch 62/2000
# 8/8 - 1s - loss: 0.7078 - auc: 0.6526 - accuracy: 0.6557 - val_loss: 0.6334 - val_auc: 0.6362 - val_accuracy: 0.6539 - 857ms/epoch - 107ms/step
# Epoch 63/2000
# 8/8 - 1s - loss: 0.7074 - auc: 0.6537 - accuracy: 0.6561 - val_loss: 0.6331 - val_auc: 0.6372 - val_accuracy: 0.6539 - 617ms/epoch - 77ms/step
# Epoch 64/2000
# 8/8 - 1s - loss: 0.7070 - auc: 0.6548 - accuracy: 0.6567 - val_loss: 0.6328 - val_auc: 0.6382 - val_accuracy: 0.6539 - 695ms/epoch - 87ms/step
# Epoch 65/2000
# 8/8 - 1s - loss: 0.7066 - auc: 0.6558 - accuracy: 0.6571 - val_loss: 0.6324 - val_auc: 0.6390 - val_accuracy: 0.6539 - 619ms/epoch - 77ms/step
# Epoch 66/2000
# 8/8 - 1s - loss: 0.7062 - auc: 0.6567 - accuracy: 0.6572 - val_loss: 0.6321 - val_auc: 0.6400 - val_accuracy: 0.6554 - 648ms/epoch - 81ms/step
# Epoch 67/2000
# 8/8 - 1s - loss: 0.7058 - auc: 0.6576 - accuracy: 0.6579 - val_loss: 0.6317 - val_auc: 0.6411 - val_accuracy: 0.6539 - 635ms/epoch - 79ms/step
# Epoch 68/2000
# 8/8 - 1s - loss: 0.7054 - auc: 0.6585 - accuracy: 0.6589 - val_loss: 0.6314 - val_auc: 0.6420 - val_accuracy: 0.6544 - 671ms/epoch - 84ms/step
# Epoch 69/2000
# 8/8 - 1s - loss: 0.7050 - auc: 0.6594 - accuracy: 0.6588 - val_loss: 0.6310 - val_auc: 0.6429 - val_accuracy: 0.6549 - 634ms/epoch - 79ms/step
# Epoch 70/2000
# 8/8 - 1s - loss: 0.7045 - auc: 0.6604 - accuracy: 0.6591 - val_loss: 0.6307 - val_auc: 0.6439 - val_accuracy: 0.6549 - 660ms/epoch - 83ms/step
# Epoch 71/2000
# 8/8 - 1s - loss: 0.7040 - auc: 0.6614 - accuracy: 0.6603 - val_loss: 0.6305 - val_auc: 0.6444 - val_accuracy: 0.6565 - 623ms/epoch - 78ms/step
# Epoch 72/2000
# 8/8 - 1s - loss: 0.7031 - auc: 0.6632 - accuracy: 0.6624 - val_loss: 0.6301 - val_auc: 0.6458 - val_accuracy: 0.6602 - 608ms/epoch - 76ms/step
# Epoch 73/2000
# 8/8 - 1s - loss: 0.7020 - auc: 0.6656 - accuracy: 0.6641 - val_loss: 0.6290 - val_auc: 0.6479 - val_accuracy: 0.6618 - 595ms/epoch - 74ms/step
# Epoch 74/2000
# 8/8 - 1s - loss: 0.7010 - auc: 0.6677 - accuracy: 0.6655 - val_loss: 0.6278 - val_auc: 0.6507 - val_accuracy: 0.6654 - 664ms/epoch - 83ms/step
# Epoch 75/2000
# 8/8 - 1s - loss: 0.7001 - auc: 0.6697 - accuracy: 0.6661 - val_loss: 0.6272 - val_auc: 0.6533 - val_accuracy: 0.6681 - 701ms/epoch - 88ms/step
# Epoch 76/2000
# 8/8 - 1s - loss: 0.6992 - auc: 0.6719 - accuracy: 0.6677 - val_loss: 0.6264 - val_auc: 0.6552 - val_accuracy: 0.6702 - 1s/epoch - 176ms/step
# Epoch 77/2000
# 8/8 - 1s - loss: 0.6984 - auc: 0.6739 - accuracy: 0.6681 - val_loss: 0.6256 - val_auc: 0.6572 - val_accuracy: 0.6696 - 1s/epoch - 128ms/step
# Epoch 78/2000
# 8/8 - 1s - loss: 0.6975 - auc: 0.6757 - accuracy: 0.6689 - val_loss: 0.6250 - val_auc: 0.6589 - val_accuracy: 0.6702 - 970ms/epoch - 121ms/step
# Epoch 79/2000
# 8/8 - 1s - loss: 0.6967 - auc: 0.6775 - accuracy: 0.6695 - val_loss: 0.6244 - val_auc: 0.6606 - val_accuracy: 0.6686 - 909ms/epoch - 114ms/step
# Epoch 80/2000
# 8/8 - 1s - loss: 0.6958 - auc: 0.6793 - accuracy: 0.6702 - val_loss: 0.6237 - val_auc: 0.6621 - val_accuracy: 0.6696 - 760ms/epoch - 95ms/step
# Epoch 81/2000
# 8/8 - 1s - loss: 0.6950 - auc: 0.6811 - accuracy: 0.6707 - val_loss: 0.6230 - val_auc: 0.6636 - val_accuracy: 0.6681 - 691ms/epoch - 86ms/step
# Epoch 82/2000
# 8/8 - 1s - loss: 0.6940 - auc: 0.6828 - accuracy: 0.6722 - val_loss: 0.6224 - val_auc: 0.6652 - val_accuracy: 0.6670 - 676ms/epoch - 84ms/step
# Epoch 83/2000
# 8/8 - 1s - loss: 0.6931 - auc: 0.6845 - accuracy: 0.6726 - val_loss: 0.6216 - val_auc: 0.6668 - val_accuracy: 0.6675 - 738ms/epoch - 92ms/step
# Epoch 84/2000
# 8/8 - 1s - loss: 0.6921 - auc: 0.6861 - accuracy: 0.6731 - val_loss: 0.6208 - val_auc: 0.6686 - val_accuracy: 0.6681 - 636ms/epoch - 80ms/step
# Epoch 85/2000
# 8/8 - 1s - loss: 0.6911 - auc: 0.6877 - accuracy: 0.6740 - val_loss: 0.6200 - val_auc: 0.6701 - val_accuracy: 0.6691 - 614ms/epoch - 77ms/step
# Epoch 86/2000
# 8/8 - 1s - loss: 0.6902 - auc: 0.6892 - accuracy: 0.6753 - val_loss: 0.6192 - val_auc: 0.6717 - val_accuracy: 0.6707 - 837ms/epoch - 105ms/step
# Epoch 87/2000
# 8/8 - 1s - loss: 0.6892 - auc: 0.6906 - accuracy: 0.6764 - val_loss: 0.6184 - val_auc: 0.6734 - val_accuracy: 0.6712 - 678ms/epoch - 85ms/step
# Epoch 88/2000
# 8/8 - 1s - loss: 0.6882 - auc: 0.6920 - accuracy: 0.6772 - val_loss: 0.6176 - val_auc: 0.6748 - val_accuracy: 0.6712 - 652ms/epoch - 81ms/step
# Epoch 89/2000
# 8/8 - 1s - loss: 0.6872 - auc: 0.6933 - accuracy: 0.6775 - val_loss: 0.6168 - val_auc: 0.6762 - val_accuracy: 0.6733 - 604ms/epoch - 76ms/step
# Epoch 90/2000
# 8/8 - 1s - loss: 0.6861 - auc: 0.6944 - accuracy: 0.6793 - val_loss: 0.6160 - val_auc: 0.6775 - val_accuracy: 0.6723 - 610ms/epoch - 76ms/step
# Epoch 91/2000
# 8/8 - 1s - loss: 0.6851 - auc: 0.6955 - accuracy: 0.6795 - val_loss: 0.6152 - val_auc: 0.6789 - val_accuracy: 0.6739 - 604ms/epoch - 76ms/step
# Epoch 92/2000
# 8/8 - 1s - loss: 0.6841 - auc: 0.6966 - accuracy: 0.6811 - val_loss: 0.6143 - val_auc: 0.6800 - val_accuracy: 0.6749 - 610ms/epoch - 76ms/step
# Epoch 93/2000
# 8/8 - 1s - loss: 0.6831 - auc: 0.6976 - accuracy: 0.6821 - val_loss: 0.6136 - val_auc: 0.6812 - val_accuracy: 0.6781 - 610ms/epoch - 76ms/step
# Epoch 94/2000
# 8/8 - 1s - loss: 0.6821 - auc: 0.6984 - accuracy: 0.6833 - val_loss: 0.6128 - val_auc: 0.6823 - val_accuracy: 0.6760 - 608ms/epoch - 76ms/step
# Epoch 95/2000
# 8/8 - 1s - loss: 0.6811 - auc: 0.6993 - accuracy: 0.6837 - val_loss: 0.6120 - val_auc: 0.6834 - val_accuracy: 0.6781 - 620ms/epoch - 78ms/step
# Epoch 96/2000
# 8/8 - 1s - loss: 0.6802 - auc: 0.7000 - accuracy: 0.6837 - val_loss: 0.6113 - val_auc: 0.6845 - val_accuracy: 0.6765 - 760ms/epoch - 95ms/step
# Epoch 97/2000
# 8/8 - 1s - loss: 0.6793 - auc: 0.7007 - accuracy: 0.6845 - val_loss: 0.6105 - val_auc: 0.6856 - val_accuracy: 0.6781 - 687ms/epoch - 86ms/step
# Epoch 98/2000
# 8/8 - 1s - loss: 0.6784 - auc: 0.7015 - accuracy: 0.6851 - val_loss: 0.6098 - val_auc: 0.6866 - val_accuracy: 0.6781 - 710ms/epoch - 89ms/step
# Epoch 99/2000
# 8/8 - 1s - loss: 0.6775 - auc: 0.7022 - accuracy: 0.6854 - val_loss: 0.6091 - val_auc: 0.6877 - val_accuracy: 0.6781 - 618ms/epoch - 77ms/step
# Epoch 100/2000
# 8/8 - 1s - loss: 0.6767 - auc: 0.7029 - accuracy: 0.6867 - val_loss: 0.6084 - val_auc: 0.6888 - val_accuracy: 0.6786 - 668ms/epoch - 84ms/step
# Epoch 101/2000
# 8/8 - 1s - loss: 0.6758 - auc: 0.7036 - accuracy: 0.6871 - val_loss: 0.6077 - val_auc: 0.6898 - val_accuracy: 0.6802 - 629ms/epoch - 79ms/step
# Epoch 102/2000
# 8/8 - 1s - loss: 0.6751 - auc: 0.7042 - accuracy: 0.6883 - val_loss: 0.6071 - val_auc: 0.6906 - val_accuracy: 0.6812 - 629ms/epoch - 79ms/step
# Epoch 103/2000
# 8/8 - 1s - loss: 0.6743 - auc: 0.7047 - accuracy: 0.6883 - val_loss: 0.6065 - val_auc: 0.6913 - val_accuracy: 0.6796 - 674ms/epoch - 84ms/step
# Epoch 104/2000
# 8/8 - 1s - loss: 0.6736 - auc: 0.7052 - accuracy: 0.6889 - val_loss: 0.6059 - val_auc: 0.6920 - val_accuracy: 0.6786 - 698ms/epoch - 87ms/step
# Epoch 105/2000
# 8/8 - 1s - loss: 0.6729 - auc: 0.7057 - accuracy: 0.6888 - val_loss: 0.6054 - val_auc: 0.6927 - val_accuracy: 0.6786 - 678ms/epoch - 85ms/step
# Epoch 106/2000
# 8/8 - 1s - loss: 0.6722 - auc: 0.7061 - accuracy: 0.6896 - val_loss: 0.6049 - val_auc: 0.6933 - val_accuracy: 0.6791 - 639ms/epoch - 80ms/step
# Epoch 107/2000
# 8/8 - 1s - loss: 0.6715 - auc: 0.7065 - accuracy: 0.6905 - val_loss: 0.6044 - val_auc: 0.6939 - val_accuracy: 0.6775 - 612ms/epoch - 77ms/step
# Epoch 108/2000
# 8/8 - 1s - loss: 0.6709 - auc: 0.7068 - accuracy: 0.6905 - val_loss: 0.6039 - val_auc: 0.6944 - val_accuracy: 0.6781 - 701ms/epoch - 88ms/step
# Epoch 109/2000
# 8/8 - 1s - loss: 0.6703 - auc: 0.7072 - accuracy: 0.6906 - val_loss: 0.6034 - val_auc: 0.6949 - val_accuracy: 0.6786 - 663ms/epoch - 83ms/step
# Epoch 110/2000
# 8/8 - 1s - loss: 0.6697 - auc: 0.7075 - accuracy: 0.6911 - val_loss: 0.6030 - val_auc: 0.6953 - val_accuracy: 0.6796 - 609ms/epoch - 76ms/step
# Epoch 111/2000
# 8/8 - 1s - loss: 0.6692 - auc: 0.7078 - accuracy: 0.6908 - val_loss: 0.6025 - val_auc: 0.6958 - val_accuracy: 0.6802 - 611ms/epoch - 76ms/step
# Epoch 112/2000
# 8/8 - 1s - loss: 0.6687 - auc: 0.7081 - accuracy: 0.6916 - val_loss: 0.6021 - val_auc: 0.6963 - val_accuracy: 0.6796 - 646ms/epoch - 81ms/step
# Epoch 113/2000
# 8/8 - 1s - loss: 0.6681 - auc: 0.7083 - accuracy: 0.6917 - val_loss: 0.6017 - val_auc: 0.6967 - val_accuracy: 0.6807 - 900ms/epoch - 112ms/step
# Epoch 114/2000
# 8/8 - 1s - loss: 0.6677 - auc: 0.7086 - accuracy: 0.6918 - val_loss: 0.6013 - val_auc: 0.6973 - val_accuracy: 0.6791 - 807ms/epoch - 101ms/step
# Epoch 115/2000
# 8/8 - 1s - loss: 0.6672 - auc: 0.7089 - accuracy: 0.6921 - val_loss: 0.6009 - val_auc: 0.6977 - val_accuracy: 0.6781 - 638ms/epoch - 80ms/step
# Epoch 116/2000
# 8/8 - 1s - loss: 0.6667 - auc: 0.7091 - accuracy: 0.6921 - val_loss: 0.6006 - val_auc: 0.6981 - val_accuracy: 0.6770 - 607ms/epoch - 76ms/step
# Epoch 117/2000
# 8/8 - 1s - loss: 0.6663 - auc: 0.7094 - accuracy: 0.6923 - val_loss: 0.6003 - val_auc: 0.6985 - val_accuracy: 0.6781 - 604ms/epoch - 75ms/step
# Epoch 118/2000
# 8/8 - 1s - loss: 0.6659 - auc: 0.7097 - accuracy: 0.6930 - val_loss: 0.5999 - val_auc: 0.6989 - val_accuracy: 0.6775 - 601ms/epoch - 75ms/step
# Epoch 119/2000
# 8/8 - 1s - loss: 0.6655 - auc: 0.7099 - accuracy: 0.6930 - val_loss: 0.5996 - val_auc: 0.6993 - val_accuracy: 0.6796 - 594ms/epoch - 74ms/step
# Epoch 120/2000
# 8/8 - 1s - loss: 0.6651 - auc: 0.7102 - accuracy: 0.6923 - val_loss: 0.5993 - val_auc: 0.6997 - val_accuracy: 0.6807 - 598ms/epoch - 75ms/step
# Epoch 121/2000
# 8/8 - 1s - loss: 0.6647 - auc: 0.7105 - accuracy: 0.6925 - val_loss: 0.5990 - val_auc: 0.7001 - val_accuracy: 0.6791 - 641ms/epoch - 80ms/step
# Epoch 122/2000
# 8/8 - 1s - loss: 0.6643 - auc: 0.7107 - accuracy: 0.6922 - val_loss: 0.5987 - val_auc: 0.7006 - val_accuracy: 0.6781 - 614ms/epoch - 77ms/step
# Epoch 123/2000
# 8/8 - 1s - loss: 0.6640 - auc: 0.7110 - accuracy: 0.6929 - val_loss: 0.5984 - val_auc: 0.7009 - val_accuracy: 0.6770 - 641ms/epoch - 80ms/step
# Epoch 124/2000
# 8/8 - 1s - loss: 0.6637 - auc: 0.7113 - accuracy: 0.6930 - val_loss: 0.5981 - val_auc: 0.7013 - val_accuracy: 0.6775 - 638ms/epoch - 80ms/step
# Epoch 125/2000
# 8/8 - 1s - loss: 0.6633 - auc: 0.7115 - accuracy: 0.6929 - val_loss: 0.5978 - val_auc: 0.7017 - val_accuracy: 0.6775 - 593ms/epoch - 74ms/step
# Epoch 126/2000
# 8/8 - 1s - loss: 0.6630 - auc: 0.7118 - accuracy: 0.6933 - val_loss: 0.5976 - val_auc: 0.7022 - val_accuracy: 0.6775 - 619ms/epoch - 77ms/step
# Epoch 127/2000
# 8/8 - 1s - loss: 0.6627 - auc: 0.7120 - accuracy: 0.6926 - val_loss: 0.5973 - val_auc: 0.7025 - val_accuracy: 0.6775 - 598ms/epoch - 75ms/step
# Epoch 128/2000
# 8/8 - 1s - loss: 0.6624 - auc: 0.7123 - accuracy: 0.6922 - val_loss: 0.5971 - val_auc: 0.7028 - val_accuracy: 0.6770 - 592ms/epoch - 74ms/step
# Epoch 129/2000
# 8/8 - 1s - loss: 0.6621 - auc: 0.7125 - accuracy: 0.6918 - val_loss: 0.5968 - val_auc: 0.7032 - val_accuracy: 0.6765 - 595ms/epoch - 74ms/step
# Epoch 130/2000
# 8/8 - 1s - loss: 0.6618 - auc: 0.7128 - accuracy: 0.6911 - val_loss: 0.5966 - val_auc: 0.7035 - val_accuracy: 0.6770 - 593ms/epoch - 74ms/step
# Epoch 131/2000
# 8/8 - 1s - loss: 0.6616 - auc: 0.7131 - accuracy: 0.6914 - val_loss: 0.5964 - val_auc: 0.7038 - val_accuracy: 0.6765 - 597ms/epoch - 75ms/step
# Epoch 132/2000
# 8/8 - 1s - loss: 0.6613 - auc: 0.7133 - accuracy: 0.6911 - val_loss: 0.5962 - val_auc: 0.7042 - val_accuracy: 0.6781 - 602ms/epoch - 75ms/step
# Epoch 133/2000
# 8/8 - 1s - loss: 0.6610 - auc: 0.7136 - accuracy: 0.6915 - val_loss: 0.5960 - val_auc: 0.7044 - val_accuracy: 0.6786 - 593ms/epoch - 74ms/step
# Epoch 134/2000
# 8/8 - 1s - loss: 0.6607 - auc: 0.7138 - accuracy: 0.6917 - val_loss: 0.5958 - val_auc: 0.7047 - val_accuracy: 0.6781 - 598ms/epoch - 75ms/step
# Epoch 135/2000
# 8/8 - 1s - loss: 0.6605 - auc: 0.7141 - accuracy: 0.6917 - val_loss: 0.5956 - val_auc: 0.7050 - val_accuracy: 0.6786 - 592ms/epoch - 74ms/step
# Epoch 136/2000
# 8/8 - 1s - loss: 0.6602 - auc: 0.7143 - accuracy: 0.6921 - val_loss: 0.5954 - val_auc: 0.7052 - val_accuracy: 0.6802 - 597ms/epoch - 75ms/step
# Epoch 137/2000
# 8/8 - 1s - loss: 0.6600 - auc: 0.7145 - accuracy: 0.6921 - val_loss: 0.5952 - val_auc: 0.7054 - val_accuracy: 0.6812 - 630ms/epoch - 79ms/step
# Epoch 138/2000
# 8/8 - 1s - loss: 0.6598 - auc: 0.7147 - accuracy: 0.6921 - val_loss: 0.5950 - val_auc: 0.7056 - val_accuracy: 0.6812 - 594ms/epoch - 74ms/step
# Epoch 139/2000
# 8/8 - 1s - loss: 0.6595 - auc: 0.7150 - accuracy: 0.6920 - val_loss: 0.5948 - val_auc: 0.7059 - val_accuracy: 0.6812 - 600ms/epoch - 75ms/step
# Epoch 140/2000
# 8/8 - 1s - loss: 0.6593 - auc: 0.7152 - accuracy: 0.6920 - val_loss: 0.5947 - val_auc: 0.7061 - val_accuracy: 0.6802 - 600ms/epoch - 75ms/step
# Epoch 141/2000
# 8/8 - 1s - loss: 0.6591 - auc: 0.7154 - accuracy: 0.6919 - val_loss: 0.5945 - val_auc: 0.7064 - val_accuracy: 0.6796 - 596ms/epoch - 75ms/step
# Epoch 142/2000
# 8/8 - 1s - loss: 0.6588 - auc: 0.7157 - accuracy: 0.6925 - val_loss: 0.5943 - val_auc: 0.7067 - val_accuracy: 0.6802 - 619ms/epoch - 77ms/step
# Epoch 143/2000
# 8/8 - 1s - loss: 0.6586 - auc: 0.7159 - accuracy: 0.6921 - val_loss: 0.5942 - val_auc: 0.7069 - val_accuracy: 0.6817 - 703ms/epoch - 88ms/step
# Epoch 144/2000
# 8/8 - 1s - loss: 0.6584 - auc: 0.7161 - accuracy: 0.6921 - val_loss: 0.5940 - val_auc: 0.7072 - val_accuracy: 0.6802 - 600ms/epoch - 75ms/step
# Epoch 145/2000
# 8/8 - 1s - loss: 0.6582 - auc: 0.7164 - accuracy: 0.6921 - val_loss: 0.5938 - val_auc: 0.7074 - val_accuracy: 0.6828 - 607ms/epoch - 76ms/step
# Epoch 146/2000
# 8/8 - 1s - loss: 0.6580 - auc: 0.7166 - accuracy: 0.6922 - val_loss: 0.5936 - val_auc: 0.7077 - val_accuracy: 0.6828 - 593ms/epoch - 74ms/step
# Epoch 147/2000
# 8/8 - 1s - loss: 0.6578 - auc: 0.7168 - accuracy: 0.6921 - val_loss: 0.5935 - val_auc: 0.7079 - val_accuracy: 0.6828 - 627ms/epoch - 78ms/step
# Epoch 148/2000
# 8/8 - 1s - loss: 0.6576 - auc: 0.7170 - accuracy: 0.6924 - val_loss: 0.5933 - val_auc: 0.7082 - val_accuracy: 0.6823 - 599ms/epoch - 75ms/step
# Epoch 149/2000
# 8/8 - 1s - loss: 0.6573 - auc: 0.7173 - accuracy: 0.6927 - val_loss: 0.5931 - val_auc: 0.7084 - val_accuracy: 0.6817 - 607ms/epoch - 76ms/step
# Epoch 150/2000
# 8/8 - 1s - loss: 0.6571 - auc: 0.7175 - accuracy: 0.6928 - val_loss: 0.5930 - val_auc: 0.7087 - val_accuracy: 0.6823 - 599ms/epoch - 75ms/step
# Epoch 151/2000
# 8/8 - 1s - loss: 0.6569 - auc: 0.7178 - accuracy: 0.6929 - val_loss: 0.5928 - val_auc: 0.7089 - val_accuracy: 0.6817 - 597ms/epoch - 75ms/step
# Epoch 152/2000
# 8/8 - 1s - loss: 0.6567 - auc: 0.7180 - accuracy: 0.6931 - val_loss: 0.5926 - val_auc: 0.7091 - val_accuracy: 0.6817 - 599ms/epoch - 75ms/step
# Epoch 153/2000
# 8/8 - 1s - loss: 0.6565 - auc: 0.7182 - accuracy: 0.6932 - val_loss: 0.5925 - val_auc: 0.7094 - val_accuracy: 0.6817 - 603ms/epoch - 75ms/step
# Epoch 154/2000
# 8/8 - 1s - loss: 0.6563 - auc: 0.7185 - accuracy: 0.6925 - val_loss: 0.5923 - val_auc: 0.7097 - val_accuracy: 0.6812 - 610ms/epoch - 76ms/step
# Epoch 155/2000
# 8/8 - 1s - loss: 0.6561 - auc: 0.7187 - accuracy: 0.6928 - val_loss: 0.5921 - val_auc: 0.7099 - val_accuracy: 0.6817 - 598ms/epoch - 75ms/step
# Epoch 156/2000
# 8/8 - 1s - loss: 0.6559 - auc: 0.7190 - accuracy: 0.6926 - val_loss: 0.5920 - val_auc: 0.7102 - val_accuracy: 0.6812 - 605ms/epoch - 76ms/step
# Epoch 157/2000
# 8/8 - 1s - loss: 0.6557 - auc: 0.7192 - accuracy: 0.6926 - val_loss: 0.5918 - val_auc: 0.7104 - val_accuracy: 0.6817 - 598ms/epoch - 75ms/step
# Epoch 158/2000
# 8/8 - 1s - loss: 0.6555 - auc: 0.7195 - accuracy: 0.6929 - val_loss: 0.5916 - val_auc: 0.7106 - val_accuracy: 0.6823 - 597ms/epoch - 75ms/step
# Epoch 159/2000
# 8/8 - 1s - loss: 0.6553 - auc: 0.7197 - accuracy: 0.6931 - val_loss: 0.5915 - val_auc: 0.7109 - val_accuracy: 0.6823 - 604ms/epoch - 75ms/step
# Epoch 160/2000
# 8/8 - 1s - loss: 0.6551 - auc: 0.7199 - accuracy: 0.6934 - val_loss: 0.5913 - val_auc: 0.7111 - val_accuracy: 0.6817 - 595ms/epoch - 74ms/step
# Epoch 161/2000
# 8/8 - 1s - loss: 0.6549 - auc: 0.7202 - accuracy: 0.6941 - val_loss: 0.5912 - val_auc: 0.7114 - val_accuracy: 0.6833 - 595ms/epoch - 74ms/step
# Epoch 162/2000
# 8/8 - 1s - loss: 0.6547 - auc: 0.7204 - accuracy: 0.6944 - val_loss: 0.5910 - val_auc: 0.7116 - val_accuracy: 0.6839 - 689ms/epoch - 86ms/step
# Epoch 163/2000
# 8/8 - 1s - loss: 0.6545 - auc: 0.7207 - accuracy: 0.6938 - val_loss: 0.5909 - val_auc: 0.7119 - val_accuracy: 0.6839 - 659ms/epoch - 82ms/step
# Epoch 164/2000
# 8/8 - 1s - loss: 0.6543 - auc: 0.7209 - accuracy: 0.6936 - val_loss: 0.5908 - val_auc: 0.7122 - val_accuracy: 0.6839 - 912ms/epoch - 114ms/step
# Epoch 165/2000
# 8/8 - 1s - loss: 0.6541 - auc: 0.7211 - accuracy: 0.6938 - val_loss: 0.5906 - val_auc: 0.7124 - val_accuracy: 0.6844 - 792ms/epoch - 99ms/step
# Epoch 166/2000
# 8/8 - 1s - loss: 0.6539 - auc: 0.7213 - accuracy: 0.6937 - val_loss: 0.5905 - val_auc: 0.7126 - val_accuracy: 0.6839 - 612ms/epoch - 77ms/step
# Epoch 167/2000
# 8/8 - 1s - loss: 0.6538 - auc: 0.7216 - accuracy: 0.6937 - val_loss: 0.5903 - val_auc: 0.7128 - val_accuracy: 0.6839 - 703ms/epoch - 88ms/step
# Epoch 168/2000
# 8/8 - 1s - loss: 0.6536 - auc: 0.7218 - accuracy: 0.6938 - val_loss: 0.5902 - val_auc: 0.7130 - val_accuracy: 0.6839 - 620ms/epoch - 78ms/step
# Epoch 169/2000
# 8/8 - 1s - loss: 0.6534 - auc: 0.7220 - accuracy: 0.6938 - val_loss: 0.5901 - val_auc: 0.7132 - val_accuracy: 0.6839 - 775ms/epoch - 97ms/step
# Epoch 170/2000
# 8/8 - 1s - loss: 0.6532 - auc: 0.7222 - accuracy: 0.6939 - val_loss: 0.5899 - val_auc: 0.7134 - val_accuracy: 0.6839 - 914ms/epoch - 114ms/step
# Epoch 171/2000
# 8/8 - 1s - loss: 0.6531 - auc: 0.7224 - accuracy: 0.6944 - val_loss: 0.5897 - val_auc: 0.7136 - val_accuracy: 0.6833 - 1s/epoch - 137ms/step
# Epoch 172/2000
# 8/8 - 1s - loss: 0.6529 - auc: 0.7226 - accuracy: 0.6943 - val_loss: 0.5896 - val_auc: 0.7139 - val_accuracy: 0.6833 - 822ms/epoch - 103ms/step
# Epoch 173/2000
# 8/8 - 1s - loss: 0.6527 - auc: 0.7228 - accuracy: 0.6944 - val_loss: 0.5895 - val_auc: 0.7141 - val_accuracy: 0.6833 - 697ms/epoch - 87ms/step
# Epoch 174/2000
# 8/8 - 1s - loss: 0.6525 - auc: 0.7230 - accuracy: 0.6952 - val_loss: 0.5893 - val_auc: 0.7143 - val_accuracy: 0.6828 - 742ms/epoch - 93ms/step
# Epoch 175/2000
# 8/8 - 1s - loss: 0.6524 - auc: 0.7232 - accuracy: 0.6954 - val_loss: 0.5892 - val_auc: 0.7146 - val_accuracy: 0.6823 - 650ms/epoch - 81ms/step
# Epoch 176/2000
# 8/8 - 1s - loss: 0.6522 - auc: 0.7234 - accuracy: 0.6955 - val_loss: 0.5890 - val_auc: 0.7148 - val_accuracy: 0.6823 - 617ms/epoch - 77ms/step
# Epoch 177/2000
# 8/8 - 1s - loss: 0.6520 - auc: 0.7236 - accuracy: 0.6952 - val_loss: 0.5889 - val_auc: 0.7150 - val_accuracy: 0.6817 - 610ms/epoch - 76ms/step
# Epoch 178/2000
# 8/8 - 1s - loss: 0.6519 - auc: 0.7238 - accuracy: 0.6953 - val_loss: 0.5887 - val_auc: 0.7153 - val_accuracy: 0.6812 - 610ms/epoch - 76ms/step
# Epoch 179/2000
# 8/8 - 1s - loss: 0.6517 - auc: 0.7240 - accuracy: 0.6957 - val_loss: 0.5886 - val_auc: 0.7154 - val_accuracy: 0.6817 - 607ms/epoch - 76ms/step
# Epoch 180/2000
# 8/8 - 1s - loss: 0.6515 - auc: 0.7242 - accuracy: 0.6961 - val_loss: 0.5884 - val_auc: 0.7156 - val_accuracy: 0.6828 - 657ms/epoch - 82ms/step
# Epoch 181/2000
# 8/8 - 1s - loss: 0.6514 - auc: 0.7244 - accuracy: 0.6963 - val_loss: 0.5883 - val_auc: 0.7159 - val_accuracy: 0.6828 - 673ms/epoch - 84ms/step
# Epoch 182/2000
# 8/8 - 1s - loss: 0.6512 - auc: 0.7246 - accuracy: 0.6961 - val_loss: 0.5881 - val_auc: 0.7160 - val_accuracy: 0.6833 - 700ms/epoch - 87ms/step
# Epoch 183/2000
# 8/8 - 1s - loss: 0.6510 - auc: 0.7248 - accuracy: 0.6963 - val_loss: 0.5880 - val_auc: 0.7163 - val_accuracy: 0.6839 - 699ms/epoch - 87ms/step
# Epoch 184/2000
# 8/8 - 1s - loss: 0.6509 - auc: 0.7250 - accuracy: 0.6963 - val_loss: 0.5878 - val_auc: 0.7165 - val_accuracy: 0.6839 - 627ms/epoch - 78ms/step
# Epoch 185/2000
# 8/8 - 1s - loss: 0.6507 - auc: 0.7252 - accuracy: 0.6965 - val_loss: 0.5877 - val_auc: 0.7168 - val_accuracy: 0.6839 - 640ms/epoch - 80ms/step
# Epoch 186/2000
# 8/8 - 1s - loss: 0.6505 - auc: 0.7255 - accuracy: 0.6966 - val_loss: 0.5875 - val_auc: 0.7170 - val_accuracy: 0.6860 - 601ms/epoch - 75ms/step
# Epoch 187/2000
# 8/8 - 1s - loss: 0.6503 - auc: 0.7257 - accuracy: 0.6969 - val_loss: 0.5874 - val_auc: 0.7172 - val_accuracy: 0.6865 - 600ms/epoch - 75ms/step
# Epoch 188/2000
# 8/8 - 1s - loss: 0.6502 - auc: 0.7259 - accuracy: 0.6973 - val_loss: 0.5872 - val_auc: 0.7174 - val_accuracy: 0.6865 - 594ms/epoch - 74ms/step
# Epoch 189/2000
# 8/8 - 1s - loss: 0.6500 - auc: 0.7261 - accuracy: 0.6971 - val_loss: 0.5870 - val_auc: 0.7177 - val_accuracy: 0.6865 - 600ms/epoch - 75ms/step
# Epoch 190/2000
# 8/8 - 1s - loss: 0.6498 - auc: 0.7263 - accuracy: 0.6971 - val_loss: 0.5869 - val_auc: 0.7180 - val_accuracy: 0.6870 - 594ms/epoch - 74ms/step
# Epoch 191/2000
# 8/8 - 1s - loss: 0.6497 - auc: 0.7265 - accuracy: 0.6972 - val_loss: 0.5867 - val_auc: 0.7182 - val_accuracy: 0.6865 - 619ms/epoch - 77ms/step
# Epoch 192/2000
# 8/8 - 1s - loss: 0.6495 - auc: 0.7267 - accuracy: 0.6973 - val_loss: 0.5866 - val_auc: 0.7184 - val_accuracy: 0.6865 - 610ms/epoch - 76ms/step
# Epoch 193/2000
# 8/8 - 1s - loss: 0.6493 - auc: 0.7269 - accuracy: 0.6977 - val_loss: 0.5864 - val_auc: 0.7186 - val_accuracy: 0.6865 - 597ms/epoch - 75ms/step
# Epoch 194/2000
# 8/8 - 1s - loss: 0.6492 - auc: 0.7271 - accuracy: 0.6977 - val_loss: 0.5863 - val_auc: 0.7189 - val_accuracy: 0.6865 - 616ms/epoch - 77ms/step
# Epoch 195/2000
# 8/8 - 1s - loss: 0.6490 - auc: 0.7273 - accuracy: 0.6977 - val_loss: 0.5862 - val_auc: 0.7190 - val_accuracy: 0.6865 - 619ms/epoch - 77ms/step
# Epoch 196/2000
# 8/8 - 1s - loss: 0.6489 - auc: 0.7275 - accuracy: 0.6980 - val_loss: 0.5860 - val_auc: 0.7192 - val_accuracy: 0.6865 - 601ms/epoch - 75ms/step
# Epoch 197/2000
# 8/8 - 1s - loss: 0.6487 - auc: 0.7277 - accuracy: 0.6981 - val_loss: 0.5859 - val_auc: 0.7194 - val_accuracy: 0.6865 - 600ms/epoch - 75ms/step
# Epoch 198/2000
# 8/8 - 1s - loss: 0.6486 - auc: 0.7279 - accuracy: 0.6986 - val_loss: 0.5857 - val_auc: 0.7196 - val_accuracy: 0.6865 - 605ms/epoch - 76ms/step
# Epoch 199/2000
# 8/8 - 1s - loss: 0.6484 - auc: 0.7280 - accuracy: 0.6986 - val_loss: 0.5856 - val_auc: 0.7197 - val_accuracy: 0.6860 - 599ms/epoch - 75ms/step
# Epoch 200/2000
# 8/8 - 1s - loss: 0.6483 - auc: 0.7282 - accuracy: 0.6987 - val_loss: 0.5855 - val_auc: 0.7200 - val_accuracy: 0.6870 - 602ms/epoch - 75ms/step
# Epoch 201/2000
# 8/8 - 1s - loss: 0.6481 - auc: 0.7284 - accuracy: 0.6988 - val_loss: 0.5853 - val_auc: 0.7202 - val_accuracy: 0.6870 - 659ms/epoch - 82ms/step
# Epoch 202/2000
# 8/8 - 1s - loss: 0.6480 - auc: 0.7286 - accuracy: 0.6989 - val_loss: 0.5852 - val_auc: 0.7203 - val_accuracy: 0.6870 - 627ms/epoch - 78ms/step
# Epoch 203/2000
# 8/8 - 1s - loss: 0.6478 - auc: 0.7287 - accuracy: 0.6994 - val_loss: 0.5851 - val_auc: 0.7205 - val_accuracy: 0.6875 - 638ms/epoch - 80ms/step
# Epoch 204/2000
# 8/8 - 1s - loss: 0.6477 - auc: 0.7289 - accuracy: 0.6995 - val_loss: 0.5849 - val_auc: 0.7207 - val_accuracy: 0.6875 - 624ms/epoch - 78ms/step
# Epoch 205/2000
# 8/8 - 1s - loss: 0.6476 - auc: 0.7291 - accuracy: 0.6998 - val_loss: 0.5848 - val_auc: 0.7209 - val_accuracy: 0.6881 - 634ms/epoch - 79ms/step
# Epoch 206/2000
# 8/8 - 1s - loss: 0.6474 - auc: 0.7292 - accuracy: 0.6997 - val_loss: 0.5847 - val_auc: 0.7211 - val_accuracy: 0.6886 - 631ms/epoch - 79ms/step
# Epoch 207/2000
# 8/8 - 1s - loss: 0.6473 - auc: 0.7294 - accuracy: 0.6999 - val_loss: 0.5846 - val_auc: 0.7212 - val_accuracy: 0.6891 - 627ms/epoch - 78ms/step
# Epoch 208/2000
# 8/8 - 1s - loss: 0.6472 - auc: 0.7295 - accuracy: 0.6999 - val_loss: 0.5844 - val_auc: 0.7214 - val_accuracy: 0.6891 - 612ms/epoch - 76ms/step
# Epoch 209/2000
# 8/8 - 1s - loss: 0.6470 - auc: 0.7297 - accuracy: 0.7000 - val_loss: 0.5843 - val_auc: 0.7216 - val_accuracy: 0.6896 - 659ms/epoch - 82ms/step
# Epoch 210/2000
# 8/8 - 1s - loss: 0.6469 - auc: 0.7298 - accuracy: 0.7000 - val_loss: 0.5842 - val_auc: 0.7217 - val_accuracy: 0.6891 - 634ms/epoch - 79ms/step
# Epoch 211/2000
# 8/8 - 1s - loss: 0.6468 - auc: 0.7300 - accuracy: 0.7004 - val_loss: 0.5840 - val_auc: 0.7219 - val_accuracy: 0.6891 - 649ms/epoch - 81ms/step
# Epoch 212/2000
# 8/8 - 1s - loss: 0.6466 - auc: 0.7302 - accuracy: 0.7004 - val_loss: 0.5839 - val_auc: 0.7221 - val_accuracy: 0.6891 - 631ms/epoch - 79ms/step
# Epoch 213/2000
# 8/8 - 1s - loss: 0.6465 - auc: 0.7303 - accuracy: 0.7003 - val_loss: 0.5838 - val_auc: 0.7223 - val_accuracy: 0.6891 - 623ms/epoch - 78ms/step
# Epoch 214/2000
# 8/8 - 1s - loss: 0.6464 - auc: 0.7305 - accuracy: 0.7002 - val_loss: 0.5836 - val_auc: 0.7225 - val_accuracy: 0.6891 - 662ms/epoch - 83ms/step
# Epoch 215/2000
# 8/8 - 1s - loss: 0.6462 - auc: 0.7307 - accuracy: 0.7003 - val_loss: 0.5835 - val_auc: 0.7227 - val_accuracy: 0.6886 - 635ms/epoch - 79ms/step
# Epoch 216/2000
# 8/8 - 1s - loss: 0.6461 - auc: 0.7308 - accuracy: 0.7004 - val_loss: 0.5833 - val_auc: 0.7229 - val_accuracy: 0.6886 - 611ms/epoch - 76ms/step
# Epoch 217/2000
# 8/8 - 1s - loss: 0.6459 - auc: 0.7310 - accuracy: 0.7004 - val_loss: 0.5832 - val_auc: 0.7230 - val_accuracy: 0.6881 - 610ms/epoch - 76ms/step
# Epoch 218/2000
# 8/8 - 1s - loss: 0.6458 - auc: 0.7312 - accuracy: 0.7007 - val_loss: 0.5830 - val_auc: 0.7232 - val_accuracy: 0.6881 - 622ms/epoch - 78ms/step
# Epoch 219/2000
# 8/8 - 1s - loss: 0.6457 - auc: 0.7313 - accuracy: 0.7010 - val_loss: 0.5829 - val_auc: 0.7234 - val_accuracy: 0.6881 - 629ms/epoch - 79ms/step
# Epoch 220/2000
# 8/8 - 1s - loss: 0.6455 - auc: 0.7315 - accuracy: 0.7013 - val_loss: 0.5828 - val_auc: 0.7236 - val_accuracy: 0.6881 - 621ms/epoch - 78ms/step
# Epoch 221/2000
# 8/8 - 1s - loss: 0.6454 - auc: 0.7317 - accuracy: 0.7015 - val_loss: 0.5826 - val_auc: 0.7238 - val_accuracy: 0.6886 - 621ms/epoch - 78ms/step
# Epoch 222/2000
# 8/8 - 1s - loss: 0.6453 - auc: 0.7319 - accuracy: 0.7019 - val_loss: 0.5824 - val_auc: 0.7240 - val_accuracy: 0.6881 - 615ms/epoch - 77ms/step
# Epoch 223/2000
# 8/8 - 1s - loss: 0.6451 - auc: 0.7320 - accuracy: 0.7016 - val_loss: 0.5823 - val_auc: 0.7242 - val_accuracy: 0.6875 - 608ms/epoch - 76ms/step
# Epoch 224/2000
# 8/8 - 1s - loss: 0.6450 - auc: 0.7322 - accuracy: 0.7021 - val_loss: 0.5822 - val_auc: 0.7243 - val_accuracy: 0.6881 - 618ms/epoch - 77ms/step
# Epoch 225/2000
# 8/8 - 1s - loss: 0.6449 - auc: 0.7324 - accuracy: 0.7021 - val_loss: 0.5821 - val_auc: 0.7245 - val_accuracy: 0.6881 - 625ms/epoch - 78ms/step
# Epoch 226/2000
# 8/8 - 1s - loss: 0.6447 - auc: 0.7325 - accuracy: 0.7024 - val_loss: 0.5820 - val_auc: 0.7247 - val_accuracy: 0.6881 - 615ms/epoch - 77ms/step
# Epoch 227/2000
# 8/8 - 1s - loss: 0.6446 - auc: 0.7327 - accuracy: 0.7028 - val_loss: 0.5818 - val_auc: 0.7249 - val_accuracy: 0.6881 - 620ms/epoch - 78ms/step
# Epoch 228/2000
# 8/8 - 1s - loss: 0.6445 - auc: 0.7329 - accuracy: 0.7030 - val_loss: 0.5817 - val_auc: 0.7250 - val_accuracy: 0.6896 - 621ms/epoch - 78ms/step
# Epoch 229/2000
# 8/8 - 1s - loss: 0.6443 - auc: 0.7330 - accuracy: 0.7033 - val_loss: 0.5816 - val_auc: 0.7251 - val_accuracy: 0.6896 - 621ms/epoch - 78ms/step
# Epoch 230/2000
# 8/8 - 1s - loss: 0.6442 - auc: 0.7332 - accuracy: 0.7037 - val_loss: 0.5815 - val_auc: 0.7253 - val_accuracy: 0.6902 - 629ms/epoch - 79ms/step
# Epoch 231/2000
# 8/8 - 1s - loss: 0.6440 - auc: 0.7334 - accuracy: 0.7036 - val_loss: 0.5814 - val_auc: 0.7254 - val_accuracy: 0.6902 - 609ms/epoch - 76ms/step
# Epoch 232/2000
# 8/8 - 1s - loss: 0.6439 - auc: 0.7336 - accuracy: 0.7034 - val_loss: 0.5813 - val_auc: 0.7255 - val_accuracy: 0.6907 - 623ms/epoch - 78ms/step
# Epoch 233/2000
# 8/8 - 1s - loss: 0.6438 - auc: 0.7338 - accuracy: 0.7032 - val_loss: 0.5812 - val_auc: 0.7257 - val_accuracy: 0.6907 - 605ms/epoch - 76ms/step
# Epoch 234/2000
# 8/8 - 1s - loss: 0.6436 - auc: 0.7339 - accuracy: 0.7034 - val_loss: 0.5810 - val_auc: 0.7258 - val_accuracy: 0.6902 - 610ms/epoch - 76ms/step
# Epoch 235/2000
# 8/8 - 1s - loss: 0.6435 - auc: 0.7341 - accuracy: 0.7034 - val_loss: 0.5809 - val_auc: 0.7260 - val_accuracy: 0.6907 - 603ms/epoch - 75ms/step
# Epoch 236/2000
# 8/8 - 1s - loss: 0.6434 - auc: 0.7342 - accuracy: 0.7036 - val_loss: 0.5808 - val_auc: 0.7261 - val_accuracy: 0.6907 - 606ms/epoch - 76ms/step
# Epoch 237/2000
# 8/8 - 1s - loss: 0.6433 - auc: 0.7344 - accuracy: 0.7033 - val_loss: 0.5807 - val_auc: 0.7263 - val_accuracy: 0.6917 - 618ms/epoch - 77ms/step
# Epoch 238/2000
# 8/8 - 1s - loss: 0.6431 - auc: 0.7346 - accuracy: 0.7035 - val_loss: 0.5805 - val_auc: 0.7265 - val_accuracy: 0.6917 - 609ms/epoch - 76ms/step
# Epoch 239/2000
# 8/8 - 1s - loss: 0.6430 - auc: 0.7347 - accuracy: 0.7032 - val_loss: 0.5804 - val_auc: 0.7266 - val_accuracy: 0.6923 - 616ms/epoch - 77ms/step
# Epoch 240/2000
# 8/8 - 1s - loss: 0.6429 - auc: 0.7349 - accuracy: 0.7033 - val_loss: 0.5803 - val_auc: 0.7268 - val_accuracy: 0.6928 - 618ms/epoch - 77ms/step
# Epoch 241/2000
# 8/8 - 1s - loss: 0.6427 - auc: 0.7350 - accuracy: 0.7033 - val_loss: 0.5802 - val_auc: 0.7270 - val_accuracy: 0.6938 - 613ms/epoch - 77ms/step
# Epoch 242/2000
# 8/8 - 1s - loss: 0.6426 - auc: 0.7351 - accuracy: 0.7034 - val_loss: 0.5801 - val_auc: 0.7272 - val_accuracy: 0.6938 - 603ms/epoch - 75ms/step
# Epoch 243/2000
# 8/8 - 1s - loss: 0.6425 - auc: 0.7353 - accuracy: 0.7036 - val_loss: 0.5799 - val_auc: 0.7273 - val_accuracy: 0.6938 - 605ms/epoch - 76ms/step
# Epoch 244/2000
# 8/8 - 1s - loss: 0.6424 - auc: 0.7354 - accuracy: 0.7038 - val_loss: 0.5798 - val_auc: 0.7275 - val_accuracy: 0.6933 - 623ms/epoch - 78ms/step
# Epoch 245/2000
# 8/8 - 1s - loss: 0.6422 - auc: 0.7356 - accuracy: 0.7040 - val_loss: 0.5797 - val_auc: 0.7276 - val_accuracy: 0.6933 - 616ms/epoch - 77ms/step
# Epoch 246/2000
# 8/8 - 1s - loss: 0.6421 - auc: 0.7357 - accuracy: 0.7039 - val_loss: 0.5796 - val_auc: 0.7278 - val_accuracy: 0.6933 - 605ms/epoch - 76ms/step
# Epoch 247/2000
# 8/8 - 1s - loss: 0.6420 - auc: 0.7359 - accuracy: 0.7038 - val_loss: 0.5794 - val_auc: 0.7280 - val_accuracy: 0.6933 - 609ms/epoch - 76ms/step
# Epoch 248/2000
# 8/8 - 1s - loss: 0.6419 - auc: 0.7360 - accuracy: 0.7039 - val_loss: 0.5793 - val_auc: 0.7281 - val_accuracy: 0.6938 - 602ms/epoch - 75ms/step
# Epoch 249/2000
# 8/8 - 1s - loss: 0.6418 - auc: 0.7361 - accuracy: 0.7038 - val_loss: 0.5792 - val_auc: 0.7283 - val_accuracy: 0.6944 - 617ms/epoch - 77ms/step
# Epoch 250/2000
# 8/8 - 1s - loss: 0.6416 - auc: 0.7363 - accuracy: 0.7038 - val_loss: 0.5791 - val_auc: 0.7285 - val_accuracy: 0.6949 - 616ms/epoch - 77ms/step
# Epoch 251/2000
# 8/8 - 1s - loss: 0.6415 - auc: 0.7364 - accuracy: 0.7038 - val_loss: 0.5790 - val_auc: 0.7287 - val_accuracy: 0.6959 - 613ms/epoch - 77ms/step
# Epoch 252/2000
# 8/8 - 1s - loss: 0.6414 - auc: 0.7366 - accuracy: 0.7038 - val_loss: 0.5788 - val_auc: 0.7288 - val_accuracy: 0.6965 - 615ms/epoch - 77ms/step
# Epoch 253/2000
# 8/8 - 1s - loss: 0.6413 - auc: 0.7367 - accuracy: 0.7042 - val_loss: 0.5787 - val_auc: 0.7290 - val_accuracy: 0.6965 - 623ms/epoch - 78ms/step
# Epoch 254/2000
# 8/8 - 1s - loss: 0.6411 - auc: 0.7369 - accuracy: 0.7040 - val_loss: 0.5786 - val_auc: 0.7292 - val_accuracy: 0.6970 - 614ms/epoch - 77ms/step
# Epoch 255/2000
# 8/8 - 1s - loss: 0.6410 - auc: 0.7370 - accuracy: 0.7040 - val_loss: 0.5784 - val_auc: 0.7294 - val_accuracy: 0.6975 - 613ms/epoch - 77ms/step
# Epoch 256/2000
# 8/8 - 1s - loss: 0.6409 - auc: 0.7372 - accuracy: 0.7042 - val_loss: 0.5783 - val_auc: 0.7296 - val_accuracy: 0.6981 - 619ms/epoch - 77ms/step
# Epoch 257/2000
# 8/8 - 1s - loss: 0.6408 - auc: 0.7373 - accuracy: 0.7044 - val_loss: 0.5782 - val_auc: 0.7297 - val_accuracy: 0.6981 - 613ms/epoch - 77ms/step
# Epoch 258/2000
# 8/8 - 1s - loss: 0.6406 - auc: 0.7375 - accuracy: 0.7044 - val_loss: 0.5780 - val_auc: 0.7299 - val_accuracy: 0.6981 - 607ms/epoch - 76ms/step
# Epoch 259/2000
# 8/8 - 1s - loss: 0.6405 - auc: 0.7376 - accuracy: 0.7044 - val_loss: 0.5779 - val_auc: 0.7301 - val_accuracy: 0.6981 - 606ms/epoch - 76ms/step
# Epoch 260/2000
# 8/8 - 1s - loss: 0.6404 - auc: 0.7378 - accuracy: 0.7044 - val_loss: 0.5778 - val_auc: 0.7303 - val_accuracy: 0.6970 - 615ms/epoch - 77ms/step
# Epoch 261/2000
# 8/8 - 1s - loss: 0.6403 - auc: 0.7379 - accuracy: 0.7044 - val_loss: 0.5776 - val_auc: 0.7304 - val_accuracy: 0.6965 - 604ms/epoch - 75ms/step
# Epoch 262/2000
# 8/8 - 1s - loss: 0.6401 - auc: 0.7380 - accuracy: 0.7046 - val_loss: 0.5775 - val_auc: 0.7306 - val_accuracy: 0.6970 - 613ms/epoch - 77ms/step
# Epoch 263/2000
# 8/8 - 1s - loss: 0.6400 - auc: 0.7382 - accuracy: 0.7048 - val_loss: 0.5774 - val_auc: 0.7307 - val_accuracy: 0.6975 - 614ms/epoch - 77ms/step
# Epoch 264/2000
# 8/8 - 1s - loss: 0.6399 - auc: 0.7383 - accuracy: 0.7052 - val_loss: 0.5772 - val_auc: 0.7309 - val_accuracy: 0.6986 - 631ms/epoch - 79ms/step
# Epoch 265/2000
# 8/8 - 1s - loss: 0.6398 - auc: 0.7385 - accuracy: 0.7052 - val_loss: 0.5771 - val_auc: 0.7311 - val_accuracy: 0.6981 - 615ms/epoch - 77ms/step
# Epoch 266/2000
# 8/8 - 1s - loss: 0.6397 - auc: 0.7386 - accuracy: 0.7053 - val_loss: 0.5769 - val_auc: 0.7313 - val_accuracy: 0.6981 - 619ms/epoch - 77ms/step
# Epoch 267/2000
# 8/8 - 1s - loss: 0.6395 - auc: 0.7388 - accuracy: 0.7056 - val_loss: 0.5768 - val_auc: 0.7315 - val_accuracy: 0.6975 - 625ms/epoch - 78ms/step
# Epoch 268/2000
# 8/8 - 1s - loss: 0.6394 - auc: 0.7389 - accuracy: 0.7057 - val_loss: 0.5766 - val_auc: 0.7317 - val_accuracy: 0.6975 - 616ms/epoch - 77ms/step
# Epoch 269/2000
# 8/8 - 1s - loss: 0.6393 - auc: 0.7391 - accuracy: 0.7058 - val_loss: 0.5764 - val_auc: 0.7320 - val_accuracy: 0.6970 - 616ms/epoch - 77ms/step
# Epoch 270/2000
# 8/8 - 1s - loss: 0.6391 - auc: 0.7393 - accuracy: 0.7057 - val_loss: 0.5763 - val_auc: 0.7323 - val_accuracy: 0.6975 - 605ms/epoch - 76ms/step
# Epoch 271/2000
# 8/8 - 1s - loss: 0.6390 - auc: 0.7394 - accuracy: 0.7060 - val_loss: 0.5761 - val_auc: 0.7325 - val_accuracy: 0.6975 - 614ms/epoch - 77ms/step
# Epoch 272/2000
# 8/8 - 1s - loss: 0.6389 - auc: 0.7395 - accuracy: 0.7066 - val_loss: 0.5760 - val_auc: 0.7326 - val_accuracy: 0.6970 - 617ms/epoch - 77ms/step
# Epoch 273/2000
# 8/8 - 1s - loss: 0.6387 - auc: 0.7397 - accuracy: 0.7068 - val_loss: 0.5759 - val_auc: 0.7328 - val_accuracy: 0.6970 - 611ms/epoch - 76ms/step
# Epoch 274/2000
# 8/8 - 1s - loss: 0.6386 - auc: 0.7398 - accuracy: 0.7070 - val_loss: 0.5757 - val_auc: 0.7329 - val_accuracy: 0.6965 - 621ms/epoch - 78ms/step
# Epoch 275/2000
# 8/8 - 1s - loss: 0.6385 - auc: 0.7399 - accuracy: 0.7073 - val_loss: 0.5756 - val_auc: 0.7331 - val_accuracy: 0.6965 - 617ms/epoch - 77ms/step
# Epoch 276/2000
# 8/8 - 1s - loss: 0.6384 - auc: 0.7401 - accuracy: 0.7072 - val_loss: 0.5755 - val_auc: 0.7333 - val_accuracy: 0.6965 - 601ms/epoch - 75ms/step
# Epoch 277/2000
# ...
# Epoch 472/2000
# 8/8 - 1s - loss: 0.6219 - auc: 0.7581 - accuracy: 0.7181 - val_loss: 0.5585 - val_auc: 0.7544 - val_accuracy: 0.7196 - 620ms/epoch - 78ms/step
# Epoch 473/2000
# 8/8 - 1s - loss: 0.6218 - auc: 0.7582 - accuracy: 0.7180 - val_loss: 0.5585 - val_auc: 0.7544 - val_accuracy: 0.7196 - 613ms/epoch - 77ms/step
# Epoch 474/2000
# 8/8 - 1s - loss: 0.6217 - auc: 0.7582 - accuracy: 0.7180 - val_loss: 0.5584 - val_auc: 0.7545 - val_accuracy: 0.7196 - 628ms/epoch - 78ms/step
# Epoch 475/2000
# 8/8 - 1s - loss: 0.6217 - auc: 0.7583 - accuracy: 0.7180 - val_loss: 0.5584 - val_auc: 0.7546 - val_accuracy: 0.7191 - 616ms/epoch - 77ms/step
# Epoch 476/2000
# 8/8 - 1s - loss: 0.6216 - auc: 0.7583 - accuracy: 0.7182 - val_loss: 0.5583 - val_auc: 0.7546 - val_accuracy: 0.7191 - 642ms/epoch - 80ms/step
# Epoch 477/2000
# 8/8 - 1s - loss: 0.6216 - auc: 0.7584 - accuracy: 0.7184 - val_loss: 0.5582 - val_auc: 0.7547 - val_accuracy: 0.7191 - 631ms/epoch - 79ms/step
# Epoch 478/2000
# 8/8 - 1s - loss: 0.6215 - auc: 0.7585 - accuracy: 0.7184 - val_loss: 0.5582 - val_auc: 0.7547 - val_accuracy: 0.7191 - 619ms/epoch - 77ms/step
# Epoch 479/2000
# 8/8 - 1s - loss: 0.6214 - auc: 0.7585 - accuracy: 0.7185 - val_loss: 0.5581 - val_auc: 0.7548 - val_accuracy: 0.7191 - 627ms/epoch - 78ms/step
# Epoch 480/2000
# 8/8 - 1s - loss: 0.6214 - auc: 0.7586 - accuracy: 0.7184 - val_loss: 0.5581 - val_auc: 0.7549 - val_accuracy: 0.7191 - 618ms/epoch - 77ms/step
# Epoch 481/2000
# 8/8 - 1s - loss: 0.6213 - auc: 0.7586 - accuracy: 0.7184 - val_loss: 0.5580 - val_auc: 0.7549 - val_accuracy: 0.7191 - 618ms/epoch - 77ms/step
# Epoch 482/2000
# 8/8 - 1s - loss: 0.6213 - auc: 0.7587 - accuracy: 0.7184 - val_loss: 0.5580 - val_auc: 0.7550 - val_accuracy: 0.7191 - 619ms/epoch - 77ms/step
# Epoch 483/2000
# 8/8 - 1s - loss: 0.6212 - auc: 0.7587 - accuracy: 0.7185 - val_loss: 0.5579 - val_auc: 0.7551 - val_accuracy: 0.7191 - 620ms/epoch - 77ms/step
# Epoch 484/2000
# 8/8 - 1s - loss: 0.6211 - auc: 0.7588 - accuracy: 0.7182 - val_loss: 0.5579 - val_auc: 0.7551 - val_accuracy: 0.7191 - 619ms/epoch - 77ms/step
# Epoch 485/2000
# 8/8 - 1s - loss: 0.6211 - auc: 0.7589 - accuracy: 0.7182 - val_loss: 0.5578 - val_auc: 0.7552 - val_accuracy: 0.7196 - 619ms/epoch - 77ms/step
# Epoch 486/2000
# 8/8 - 1s - loss: 0.6210 - auc: 0.7589 - accuracy: 0.7183 - val_loss: 0.5577 - val_auc: 0.7552 - val_accuracy: 0.7196 - 618ms/epoch - 77ms/step
# Epoch 487/2000
# 8/8 - 1s - loss: 0.6210 - auc: 0.7590 - accuracy: 0.7183 - val_loss: 0.5577 - val_auc: 0.7553 - val_accuracy: 0.7196 - 621ms/epoch - 78ms/step
# Epoch 488/2000
# 8/8 - 1s - loss: 0.6209 - auc: 0.7590 - accuracy: 0.7183 - val_loss: 0.5576 - val_auc: 0.7554 - val_accuracy: 0.7196 - 616ms/epoch - 77ms/step
# Epoch 489/2000
# 8/8 - 1s - loss: 0.6208 - auc: 0.7591 - accuracy: 0.7184 - val_loss: 0.5576 - val_auc: 0.7554 - val_accuracy: 0.7196 - 619ms/epoch - 77ms/step
# Epoch 490/2000
# 8/8 - 1s - loss: 0.6208 - auc: 0.7592 - accuracy: 0.7184 - val_loss: 0.5575 - val_auc: 0.7555 - val_accuracy: 0.7201 - 621ms/epoch - 78ms/step
# Epoch 491/2000
# 8/8 - 1s - loss: 0.6207 - auc: 0.7592 - accuracy: 0.7185 - val_loss: 0.5574 - val_auc: 0.7555 - val_accuracy: 0.7207 - 628ms/epoch - 79ms/step
# Epoch 492/2000
# 8/8 - 1s - loss: 0.6207 - auc: 0.7593 - accuracy: 0.7186 - val_loss: 0.5574 - val_auc: 0.7556 - val_accuracy: 0.7207 - 633ms/epoch - 79ms/step
# Epoch 493/2000
# 8/8 - 1s - loss: 0.6206 - auc: 0.7593 - accuracy: 0.7186 - val_loss: 0.5573 - val_auc: 0.7557 - val_accuracy: 0.7201 - 632ms/epoch - 79ms/step
# Epoch 494/2000
# 8/8 - 1s - loss: 0.6205 - auc: 0.7594 - accuracy: 0.7187 - val_loss: 0.5573 - val_auc: 0.7558 - val_accuracy: 0.7207 - 627ms/epoch - 78ms/step
# Epoch 495/2000
# 8/8 - 1s - loss: 0.6205 - auc: 0.7595 - accuracy: 0.7187 - val_loss: 0.5572 - val_auc: 0.7558 - val_accuracy: 0.7207 - 624ms/epoch - 78ms/step
# Epoch 496/2000
# 8/8 - 1s - loss: 0.6204 - auc: 0.7595 - accuracy: 0.7186 - val_loss: 0.5572 - val_auc: 0.7559 - val_accuracy: 0.7201 - 616ms/epoch - 77ms/step
# Epoch 497/2000
# 8/8 - 1s - loss: 0.6204 - auc: 0.7596 - accuracy: 0.7188 - val_loss: 0.5571 - val_auc: 0.7560 - val_accuracy: 0.7201 - 636ms/epoch - 79ms/step
# Epoch 498/2000
# 8/8 - 1s - loss: 0.6203 - auc: 0.7596 - accuracy: 0.7186 - val_loss: 0.5571 - val_auc: 0.7560 - val_accuracy: 0.7201 - 618ms/epoch - 77ms/step
# Epoch 499/2000
# 8/8 - 1s - loss: 0.6203 - auc: 0.7597 - accuracy: 0.7186 - val_loss: 0.5570 - val_auc: 0.7561 - val_accuracy: 0.7201 - 616ms/epoch - 77ms/step
# Epoch 500/2000
# 8/8 - 1s - loss: 0.6202 - auc: 0.7598 - accuracy: 0.7184 - val_loss: 0.5569 - val_auc: 0.7562 - val_accuracy: 0.7201 - 619ms/epoch - 77ms/step
# Epoch 501/2000
# 8/8 - 1s - loss: 0.6201 - auc: 0.7598 - accuracy: 0.7185 - val_loss: 0.5569 - val_auc: 0.7562 - val_accuracy: 0.7196 - 634ms/epoch - 79ms/step
# Epoch 502/2000
# 8/8 - 1s - loss: 0.6201 - auc: 0.7599 - accuracy: 0.7184 - val_loss: 0.5568 - val_auc: 0.7563 - val_accuracy: 0.7196 - 616ms/epoch - 77ms/step
# Epoch 503/2000
# 8/8 - 1s - loss: 0.6200 - auc: 0.7599 - accuracy: 0.7186 - val_loss: 0.5568 - val_auc: 0.7564 - val_accuracy: 0.7201 - 626ms/epoch - 78ms/step
# Epoch 504/2000
# 8/8 - 1s - loss: 0.6200 - auc: 0.7600 - accuracy: 0.7187 - val_loss: 0.5567 - val_auc: 0.7564 - val_accuracy: 0.7201 - 613ms/epoch - 77ms/step
# Epoch 505/2000
# 8/8 - 1s - loss: 0.6199 - auc: 0.7600 - accuracy: 0.7189 - val_loss: 0.5566 - val_auc: 0.7565 - val_accuracy: 0.7201 - 630ms/epoch - 79ms/step
# Epoch 506/2000
# 8/8 - 1s - loss: 0.6198 - auc: 0.7601 - accuracy: 0.7188 - val_loss: 0.5566 - val_auc: 0.7566 - val_accuracy: 0.7196 - 617ms/epoch - 77ms/step
# Epoch 507/2000
# 8/8 - 1s - loss: 0.6198 - auc: 0.7602 - accuracy: 0.7188 - val_loss: 0.5565 - val_auc: 0.7566 - val_accuracy: 0.7201 - 614ms/epoch - 77ms/step
# Epoch 508/2000
# 8/8 - 1s - loss: 0.6197 - auc: 0.7602 - accuracy: 0.7190 - val_loss: 0.5565 - val_auc: 0.7567 - val_accuracy: 0.7207 - 632ms/epoch - 79ms/step
# Epoch 509/2000
# 8/8 - 1s - loss: 0.6197 - auc: 0.7603 - accuracy: 0.7190 - val_loss: 0.5564 - val_auc: 0.7568 - val_accuracy: 0.7207 - 633ms/epoch - 79ms/step
# Epoch 510/2000
# 8/8 - 1s - loss: 0.6196 - auc: 0.7603 - accuracy: 0.7192 - val_loss: 0.5564 - val_auc: 0.7568 - val_accuracy: 0.7207 - 626ms/epoch - 78ms/step
# Epoch 511/2000
# 8/8 - 1s - loss: 0.6195 - auc: 0.7604 - accuracy: 0.7192 - val_loss: 0.5563 - val_auc: 0.7569 - val_accuracy: 0.7207 - 621ms/epoch - 78ms/step
# Epoch 512/2000
# 8/8 - 1s - loss: 0.6195 - auc: 0.7604 - accuracy: 0.7192 - val_loss: 0.5563 - val_auc: 0.7569 - val_accuracy: 0.7196 - 618ms/epoch - 77ms/step
# Epoch 513/2000
# 8/8 - 1s - loss: 0.6194 - auc: 0.7605 - accuracy: 0.7193 - val_loss: 0.5562 - val_auc: 0.7570 - val_accuracy: 0.7196 - 628ms/epoch - 78ms/step
# Epoch 514/2000
# 8/8 - 1s - loss: 0.6194 - auc: 0.7606 - accuracy: 0.7194 - val_loss: 0.5561 - val_auc: 0.7570 - val_accuracy: 0.7196 - 629ms/epoch - 79ms/step
# Epoch 515/2000
# 8/8 - 1s - loss: 0.6193 - auc: 0.7606 - accuracy: 0.7196 - val_loss: 0.5561 - val_auc: 0.7571 - val_accuracy: 0.7207 - 633ms/epoch - 79ms/step
# Epoch 516/2000
# 8/8 - 1s - loss: 0.6193 - auc: 0.7607 - accuracy: 0.7196 - val_loss: 0.5560 - val_auc: 0.7571 - val_accuracy: 0.7212 - 637ms/epoch - 80ms/step
# Epoch 517/2000
# 8/8 - 1s - loss: 0.6192 - auc: 0.7607 - accuracy: 0.7196 - val_loss: 0.5560 - val_auc: 0.7572 - val_accuracy: 0.7212 - 619ms/epoch - 77ms/step
# Epoch 518/2000
# 8/8 - 1s - loss: 0.6192 - auc: 0.7608 - accuracy: 0.7196 - val_loss: 0.5559 - val_auc: 0.7573 - val_accuracy: 0.7207 - 620ms/epoch - 78ms/step
# Epoch 519/2000
# 8/8 - 1s - loss: 0.6191 - auc: 0.7608 - accuracy: 0.7198 - val_loss: 0.5559 - val_auc: 0.7573 - val_accuracy: 0.7212 - 632ms/epoch - 79ms/step
# Epoch 520/2000
# 8/8 - 1s - loss: 0.6190 - auc: 0.7609 - accuracy: 0.7199 - val_loss: 0.5558 - val_auc: 0.7574 - val_accuracy: 0.7212 - 629ms/epoch - 79ms/step
# Epoch 521/2000
# 8/8 - 1s - loss: 0.6190 - auc: 0.7610 - accuracy: 0.7202 - val_loss: 0.5558 - val_auc: 0.7574 - val_accuracy: 0.7217 - 644ms/epoch - 80ms/step
# Epoch 522/2000
# 8/8 - 1s - loss: 0.6189 - auc: 0.7610 - accuracy: 0.7202 - val_loss: 0.5557 - val_auc: 0.7574 - val_accuracy: 0.7223 - 630ms/epoch - 79ms/step
# Epoch 523/2000
# 8/8 - 1s - loss: 0.6189 - auc: 0.7611 - accuracy: 0.7204 - val_loss: 0.5557 - val_auc: 0.7575 - val_accuracy: 0.7223 - 633ms/epoch - 79ms/step
# Epoch 524/2000
# 8/8 - 1s - loss: 0.6188 - auc: 0.7611 - accuracy: 0.7205 - val_loss: 0.5556 - val_auc: 0.7575 - val_accuracy: 0.7217 - 631ms/epoch - 79ms/step
# Epoch 525/2000
# 8/8 - 1s - loss: 0.6188 - auc: 0.7612 - accuracy: 0.7204 - val_loss: 0.5556 - val_auc: 0.7576 - val_accuracy: 0.7223 - 613ms/epoch - 77ms/step
# Epoch 526/2000
# 8/8 - 1s - loss: 0.6187 - auc: 0.7612 - accuracy: 0.7203 - val_loss: 0.5555 - val_auc: 0.7577 - val_accuracy: 0.7223 - 620ms/epoch - 78ms/step
# Epoch 527/2000
# 8/8 - 1s - loss: 0.6187 - auc: 0.7613 - accuracy: 0.7203 - val_loss: 0.5554 - val_auc: 0.7577 - val_accuracy: 0.7223 - 637ms/epoch - 80ms/step
# Epoch 528/2000
# 8/8 - 1s - loss: 0.6186 - auc: 0.7613 - accuracy: 0.7205 - val_loss: 0.5554 - val_auc: 0.7578 - val_accuracy: 0.7223 - 616ms/epoch - 77ms/step
# Epoch 529/2000
# 8/8 - 1s - loss: 0.6185 - auc: 0.7614 - accuracy: 0.7205 - val_loss: 0.5553 - val_auc: 0.7579 - val_accuracy: 0.7223 - 620ms/epoch - 77ms/step
# Epoch 530/2000
# 8/8 - 1s - loss: 0.6185 - auc: 0.7614 - accuracy: 0.7203 - val_loss: 0.5553 - val_auc: 0.7579 - val_accuracy: 0.7223 - 621ms/epoch - 78ms/step
# Epoch 531/2000
# 8/8 - 1s - loss: 0.6184 - auc: 0.7615 - accuracy: 0.7203 - val_loss: 0.5552 - val_auc: 0.7580 - val_accuracy: 0.7223 - 615ms/epoch - 77ms/step
# Epoch 532/2000
# 8/8 - 1s - loss: 0.6184 - auc: 0.7615 - accuracy: 0.7205 - val_loss: 0.5552 - val_auc: 0.7581 - val_accuracy: 0.7223 - 616ms/epoch - 77ms/step
# Epoch 533/2000
# 8/8 - 1s - loss: 0.6183 - auc: 0.7616 - accuracy: 0.7205 - val_loss: 0.5551 - val_auc: 0.7581 - val_accuracy: 0.7223 - 620ms/epoch - 77ms/step
# Epoch 534/2000
# 8/8 - 1s - loss: 0.6183 - auc: 0.7616 - accuracy: 0.7205 - val_loss: 0.5551 - val_auc: 0.7582 - val_accuracy: 0.7217 - 619ms/epoch - 77ms/step
# Epoch 535/2000
# 8/8 - 1s - loss: 0.6182 - auc: 0.7617 - accuracy: 0.7205 - val_loss: 0.5550 - val_auc: 0.7582 - val_accuracy: 0.7212 - 630ms/epoch - 79ms/step
# Epoch 536/2000
# 8/8 - 1s - loss: 0.6182 - auc: 0.7617 - accuracy: 0.7206 - val_loss: 0.5550 - val_auc: 0.7583 - val_accuracy: 0.7207 - 626ms/epoch - 78ms/step
# Epoch 537/2000
# 8/8 - 1s - loss: 0.6181 - auc: 0.7618 - accuracy: 0.7206 - val_loss: 0.5549 - val_auc: 0.7584 - val_accuracy: 0.7201 - 620ms/epoch - 78ms/step
# Epoch 538/2000
# 8/8 - 1s - loss: 0.6181 - auc: 0.7618 - accuracy: 0.7207 - val_loss: 0.5549 - val_auc: 0.7584 - val_accuracy: 0.7196 - 626ms/epoch - 78ms/step
# Epoch 539/2000
# 8/8 - 1s - loss: 0.6180 - auc: 0.7619 - accuracy: 0.7209 - val_loss: 0.5548 - val_auc: 0.7585 - val_accuracy: 0.7196 - 630ms/epoch - 79ms/step
# Epoch 540/2000
# 8/8 - 1s - loss: 0.6180 - auc: 0.7620 - accuracy: 0.7208 - val_loss: 0.5548 - val_auc: 0.7585 - val_accuracy: 0.7191 - 626ms/epoch - 78ms/step
# Epoch 541/2000
# 8/8 - 1s - loss: 0.6179 - auc: 0.7620 - accuracy: 0.7210 - val_loss: 0.5547 - val_auc: 0.7586 - val_accuracy: 0.7191 - 626ms/epoch - 78ms/step
# Epoch 542/2000
# 8/8 - 1s - loss: 0.6179 - auc: 0.7621 - accuracy: 0.7211 - val_loss: 0.5547 - val_auc: 0.7586 - val_accuracy: 0.7191 - 632ms/epoch - 79ms/step
# Epoch 543/2000
# 8/8 - 1s - loss: 0.6178 - auc: 0.7621 - accuracy: 0.7212 - val_loss: 0.5546 - val_auc: 0.7587 - val_accuracy: 0.7191 - 630ms/epoch - 79ms/step
# Epoch 544/2000
# 8/8 - 1s - loss: 0.6178 - auc: 0.7622 - accuracy: 0.7212 - val_loss: 0.5546 - val_auc: 0.7587 - val_accuracy: 0.7196 - 616ms/epoch - 77ms/step
# Epoch 545/2000
# 8/8 - 1s - loss: 0.6177 - auc: 0.7622 - accuracy: 0.7213 - val_loss: 0.5546 - val_auc: 0.7587 - val_accuracy: 0.7207 - 630ms/epoch - 79ms/step
# Epoch 546/2000
# 8/8 - 1s - loss: 0.6176 - auc: 0.7623 - accuracy: 0.7212 - val_loss: 0.5545 - val_auc: 0.7588 - val_accuracy: 0.7207 - 621ms/epoch - 78ms/step
# Epoch 547/2000
# 8/8 - 1s - loss: 0.6176 - auc: 0.7623 - accuracy: 0.7212 - val_loss: 0.5545 - val_auc: 0.7588 - val_accuracy: 0.7207 - 616ms/epoch - 77ms/step
# Epoch 548/2000
# 8/8 - 1s - loss: 0.6175 - auc: 0.7624 - accuracy: 0.7212 - val_loss: 0.5544 - val_auc: 0.7589 - val_accuracy: 0.7207 - 619ms/epoch - 77ms/step
# Epoch 549/2000
# 8/8 - 1s - loss: 0.6175 - auc: 0.7624 - accuracy: 0.7211 - val_loss: 0.5544 - val_auc: 0.7589 - val_accuracy: 0.7196 - 616ms/epoch - 77ms/step
# Epoch 550/2000
# 8/8 - 1s - loss: 0.6174 - auc: 0.7625 - accuracy: 0.7211 - val_loss: 0.5543 - val_auc: 0.7589 - val_accuracy: 0.7201 - 619ms/epoch - 77ms/step
# Epoch 551/2000
# 8/8 - 1s - loss: 0.6174 - auc: 0.7625 - accuracy: 0.7212 - val_loss: 0.5543 - val_auc: 0.7590 - val_accuracy: 0.7196 - 622ms/epoch - 78ms/step
# Epoch 552/2000
# 8/8 - 1s - loss: 0.6173 - auc: 0.7626 - accuracy: 0.7212 - val_loss: 0.5542 - val_auc: 0.7590 - val_accuracy: 0.7196 - 619ms/epoch - 77ms/step
# Epoch 553/2000
# 8/8 - 1s - loss: 0.6173 - auc: 0.7626 - accuracy: 0.7212 - val_loss: 0.5542 - val_auc: 0.7591 - val_accuracy: 0.7196 - 617ms/epoch - 77ms/step
# Epoch 554/2000
# 8/8 - 1s - loss: 0.6172 - auc: 0.7627 - accuracy: 0.7212 - val_loss: 0.5541 - val_auc: 0.7592 - val_accuracy: 0.7191 - 634ms/epoch - 79ms/step
# Epoch 555/2000
# 8/8 - 1s - loss: 0.6172 - auc: 0.7627 - accuracy: 0.7213 - val_loss: 0.5541 - val_auc: 0.7592 - val_accuracy: 0.7191 - 622ms/epoch - 78ms/step
# Epoch 556/2000
# 8/8 - 1s - loss: 0.6171 - auc: 0.7628 - accuracy: 0.7212 - val_loss: 0.5540 - val_auc: 0.7593 - val_accuracy: 0.7191 - 613ms/epoch - 77ms/step
# Epoch 557/2000
# 8/8 - 1s - loss: 0.6171 - auc: 0.7628 - accuracy: 0.7213 - val_loss: 0.5540 - val_auc: 0.7594 - val_accuracy: 0.7191 - 630ms/epoch - 79ms/step
# Epoch 558/2000
# 8/8 - 1s - loss: 0.6170 - auc: 0.7629 - accuracy: 0.7213 - val_loss: 0.5539 - val_auc: 0.7594 - val_accuracy: 0.7186 - 622ms/epoch - 78ms/step
# Epoch 559/2000
# 8/8 - 1s - loss: 0.6170 - auc: 0.7629 - accuracy: 0.7213 - val_loss: 0.5539 - val_auc: 0.7595 - val_accuracy: 0.7186 - 615ms/epoch - 77ms/step
# Epoch 560/2000
# 8/8 - 1s - loss: 0.6169 - auc: 0.7630 - accuracy: 0.7212 - val_loss: 0.5538 - val_auc: 0.7595 - val_accuracy: 0.7186 - 618ms/epoch - 77ms/step
# Epoch 561/2000
# 8/8 - 1s - loss: 0.6169 - auc: 0.7630 - accuracy: 0.7207 - val_loss: 0.5538 - val_auc: 0.7596 - val_accuracy: 0.7186 - 622ms/epoch - 78ms/step
# Epoch 562/2000
# 8/8 - 1s - loss: 0.6168 - auc: 0.7631 - accuracy: 0.7209 - val_loss: 0.5537 - val_auc: 0.7596 - val_accuracy: 0.7186 - 616ms/epoch - 77ms/step
# Epoch 563/2000
# 8/8 - 1s - loss: 0.6168 - auc: 0.7631 - accuracy: 0.7210 - val_loss: 0.5537 - val_auc: 0.7597 - val_accuracy: 0.7186 - 619ms/epoch - 77ms/step
# Epoch 564/2000
# 8/8 - 1s - loss: 0.6167 - auc: 0.7632 - accuracy: 0.7211 - val_loss: 0.5536 - val_auc: 0.7598 - val_accuracy: 0.7180 - 614ms/epoch - 77ms/step
# Epoch 565/2000
# 8/8 - 1s - loss: 0.6167 - auc: 0.7632 - accuracy: 0.7211 - val_loss: 0.5536 - val_auc: 0.7598 - val_accuracy: 0.7175 - 620ms/epoch - 77ms/step
# Epoch 566/2000
# 8/8 - 1s - loss: 0.6166 - auc: 0.7633 - accuracy: 0.7210 - val_loss: 0.5535 - val_auc: 0.7599 - val_accuracy: 0.7175 - 617ms/epoch - 77ms/step
# Epoch 567/2000
# 8/8 - 1s - loss: 0.6166 - auc: 0.7634 - accuracy: 0.7207 - val_loss: 0.5535 - val_auc: 0.7599 - val_accuracy: 0.7180 - 617ms/epoch - 77ms/step
# Epoch 568/2000
# 8/8 - 1s - loss: 0.6165 - auc: 0.7634 - accuracy: 0.7207 - val_loss: 0.5534 - val_auc: 0.7600 - val_accuracy: 0.7175 - 619ms/epoch - 77ms/step
# Epoch 569/2000
# 8/8 - 1s - loss: 0.6164 - auc: 0.7635 - accuracy: 0.7208 - val_loss: 0.5534 - val_auc: 0.7600 - val_accuracy: 0.7165 - 616ms/epoch - 77ms/step
# Epoch 570/2000
# 8/8 - 1s - loss: 0.6164 - auc: 0.7636 - accuracy: 0.7210 - val_loss: 0.5533 - val_auc: 0.7600 - val_accuracy: 0.7154 - 616ms/epoch - 77ms/step
# Epoch 571/2000
# 8/8 - 1s - loss: 0.6163 - auc: 0.7636 - accuracy: 0.7209 - val_loss: 0.5533 - val_auc: 0.7600 - val_accuracy: 0.7154 - 623ms/epoch - 78ms/step
# Epoch 572/2000
# 8/8 - 1s - loss: 0.6163 - auc: 0.7637 - accuracy: 0.7209 - val_loss: 0.5532 - val_auc: 0.7601 - val_accuracy: 0.7154 - 632ms/epoch - 79ms/step

# %% [markdown]
# # Evaluate Model

# %% [markdown]
# ## Examining Training Performance

# %%
def plot_history(history):
    acc = history.history["accuracy"]
    loss = history.history["loss"]
    val_loss = history.history["val_loss"]
    val_accuracy = history.history["val_accuracy"]
    
    x = range(1, len(acc) + 1)
    
    plt.figure(figsize=(12,5))
    plt.subplot(1, 2, 1)
    plt.plot(x, acc, "b", label="training_acc")
    plt.plot(x, val_accuracy, "r", label="val_acc")
    plt.title("Accuracy")
    
    plt.subplot(1, 2, 2)
    plt.plot(x, loss, "b", label="training_loss")
    plt.plot(x, val_loss, "r", label="val_loss")
    plt.title("Loss")
    
plot_history(history)

# %% [markdown]
# ## Evaluating Model Performance on Unseen Data

# %%
results = model.evaluate(test_ds)
# Out:
# 2023-03-29 15:55:08.162797: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 1424 of 19017
# 2023-03-29 15:55:18.162246: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 2869 of 19017
# 2023-03-29 15:55:28.160188: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 4312 of 19017
# 2023-03-29 15:55:38.161253: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 5755 of 19017
# 2023-03-29 15:55:48.161223: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 7199 of 19017
# 2023-03-29 15:55:58.159992: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 8642 of 19017
# 2023-03-29 15:56:08.161907: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 10087 of 19017
# 2023-03-29 15:56:18.160003: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 11531 of 19017
# 2023-03-29 15:56:28.159072: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 12976 of 19017
# 2023-03-29 15:56:38.157573: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 14422 of 19017
# 2023-03-29 15:56:48.157383: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 15849 of 19017
# 2023-03-29 15:56:58.161731: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 17279 of 19017
# 2023-03-29 15:57:08.162558: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 18714 of 19017
# 2023-03-29 15:57:10.236663: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:417] Shuffle buffer filled.
# 1/1 [==============================] - 132s 132s/step - loss: 0.5552 - auc: 0.7542 - accuracy: 0.7166

# %%
for num, metric in enumerate(model.metrics_names):
    print(f"{metric}: {results[num]}")
# Out:
# loss: 0.5551586747169495
# auc: 0.7541762590408325
# accuracy: 0.7166141271591187

# %%
if results[1] > .80 and results[0] < .30:
    model.save(f"LOSS_{round(results[0],2)}_ACC_{round(results[1],2)}_AUC_{round(results[2],2)}")
else:
    print("Shit's A Dud!") #55-75-71
# Out:
# Shit's A Dud!

# %% [markdown]
# ## Evaluating Performance on Entire Dataset

# %%
x_ds = []
y_ds = []

for data in ds.as_numpy_iterator():
    x_ds.append(list(data[0]))
    y_ds.append(data[1])
# Out:
# 2023-03-29 15:57:20.541464: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 1443 of 19017
# 2023-03-29 15:57:30.544167: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 2832 of 19017
# 2023-03-29 15:57:40.544289: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 4199 of 19017
# 2023-03-29 15:57:50.545839: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 5630 of 19017
# 2023-03-29 15:58:00.546813: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 7041 of 19017
# 2023-03-29 15:58:10.547898: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 8469 of 19017
# 2023-03-29 15:58:20.542369: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 9904 of 19017
# 2023-03-29 15:58:30.545833: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 11338 of 19017
# 2023-03-29 15:58:40.541193: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 12773 of 19017
# 2023-03-29 15:58:50.541463: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 14208 of 19017
# 2023-03-29 15:59:00.547115: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 15644 of 19017
# 2023-03-29 15:59:10.543301: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 17031 of 19017
# 2023-03-29 15:59:20.544246: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 18475 of 19017
# 2023-03-29 15:59:24.246323: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:417] Shuffle buffer filled.

# %%
predictions = model.predict(ds.batch(2056))
# Out:
# 2023-03-29 15:59:36.063564: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 1430 of 19017
# 2023-03-29 15:59:46.064344: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 2863 of 19017
# 2023-03-29 15:59:56.061577: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 4295 of 19017
# 2023-03-29 16:00:06.066413: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 5730 of 19017
# 2023-03-29 16:00:16.066249: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 7162 of 19017
# 2023-03-29 16:00:26.067260: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 8596 of 19017
# 2023-03-29 16:00:36.063639: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 10028 of 19017
# 2023-03-29 16:00:46.062234: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 11459 of 19017
# 2023-03-29 16:00:56.064451: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 12893 of 19017
# 2023-03-29 16:01:06.064320: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 14308 of 19017
# 2023-03-29 16:01:16.064141: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 15775 of 19017
# 2023-03-29 16:01:26.063399: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 17244 of 19017
# 2023-03-29 16:01:36.062767: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 18712 of 19017
#       4/Unknown - 132s 18ms/step
# 2023-03-29 16:01:38.100210: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:417] Shuffle buffer filled.
# 10/10 [==============================] - 132s 24ms/step

# %%
def plot_roc_curve(fpr, tpr):
    plt.plot(fpr, tpr, color='orange', label='ROC')
    plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend()
    plt.show()
# Computing manually fpr, tpr, thresholds and roc auc 
fpr, tpr, thresholds = roc_curve(y_ds, predictions)
roc_auc = auc(fpr, tpr)
print("ROC_AUC Score : ",roc_auc)
print("Function for ROC_AUC Score : ",roc_auc_score(y_ds, predictions)) # Function present
optimal_idx = np.argmax(tpr - fpr)
optimal_threshold = thresholds[optimal_idx]
print("Threshold value is:", optimal_threshold)
plot_roc_curve(fpr, tpr)
#76
# Out:
# ROC_AUC Score :  0.760349958504506
# Function for ROC_AUC Score :  0.760349958504506
# Threshold value is: 0.5853949

# %%
adj_predictions = [1 if i[0] > optimal_threshold else 0 for i in predictions]
print(accuracy_score(y_ds, adj_predictions))
print(roc_auc_score(y_ds, adj_predictions))
#69 - 76
# Out:
# 0.7009099994739888
# 0.6962493959432305
